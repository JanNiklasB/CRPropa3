# %% [markdown]
# # Electromagnetic cascade example
#
# This is a simple 1D example of gamma-ray propagation over cosmological distances.
# Note that only pair production and inverse Compton scattering are relevant for the energy range of this example.
# Moreover, the radio background is negligible for the energy range below PeV.

# %%
from crpropa import *

dsrc = redshift2ComovingDistance(0.14)

electrons = True
photons = True

thinning = 0.90 # if 0, no thinning; speeds up the simulations considerably

cmb = CMB()
ebl = IRB_Gilmore12()
crb = URB_Nitu21()

sim = ModuleList()
sim.add(SimplePropagation())
sim.add(Redshift())
sim.add(EMPairProduction(cmb, electrons, thinning))
sim.add(EMPairProduction(ebl, electrons, thinning))
# sim.add(EMPairProduction(crb, electrons, thinning)) 
# sim.add(EMDoublePairProduction(cmb, electrons, thinning))
# sim.add(EMDoublePairProduction(ebl, electrons, thinning))
# sim.add(EMDoublePairProduction(crb, electrons, thinning))
sim.add(EMInverseComptonScattering(cmb, photons, thinning))
sim.add(EMInverseComptonScattering(ebl, photons, thinning))
# sim.add(EMInverseComptonScattering(crb, photons, thinning))
# sim.add(EMTripletPairProduction(cmb, electrons, thinning))
# sim.add(EMTripletPairProduction(ebl, electrons, thinning))
# sim.add(EMTripletPairProduction(crb, electrons, thinning))
sim.add(MinimumEnergy(10 * GeV))

obs = Observer()
obs.add(Observer1D())
obs.add(ObserverElectronVeto()) # we are only interested in photons
output = TextOutput('cascade_1d.txt', Output.Event1D)
output.setEnergyScale(eV)
output.enable(output.WeightColumn) # this is required if thinning > 0
output.disable(output.CandidateTagColumn) # not needed in this analysis
obs.onDetection(output)

source = Source()
source.add(SourcePosition(Vector3d(dsrc, 0, 0)))
source.add(SourceRedshift1D())
source.add(SourceParticleType(22))
source.add(SourcePowerLawSpectrum(10 * GeV, 10 * TeV, -1.5)) # intrinsic source spectrum
# source.add(SourceEnergy(20 * TeV)) # a monochromatic intrinsic spectrum

sim.add(obs)
sim.setShowProgress(True)
sim.run(source, 10000, True)

output.close()
# Out:
# crpropa::ModuleList: Number of Threads: 32
# Run ModuleList
#   Started Wed Jul 22 02:46:34 2026 : [>         ]   2%    Finish in: 00:00:00
# 2026-07-22 02:46:34 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:46:34 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:46:34 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:46:34 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:46:34 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:46:34 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [>         ]   3%    Finish in: 00:00:32
# 2026-07-22 02:46:35 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:46:36 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:46:36 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [>         ]   4%    Finish in: 00:00:47
# 2026-07-22 02:46:36 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:46:36 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:46:36 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [>         ]   6%    Finish in: 00:00:46
# 2026-07-22 02:46:38 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [>         ]   7%    Finish in: 00:00:53
# 2026-07-22 02:46:38 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:46:38 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [>         ]   8%    Finish in: 00:00:45
# 2026-07-22 02:46:39 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [=>        ]  12%    Finish in: 00:00:43
# 2026-07-22 02:46:40 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [=>        ]  15%    Finish in: 00:00:45
# 2026-07-22 02:46:42 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [=>        ]  16%    Finish in: 00:00:47
# 2026-07-22 02:46:43 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [=>        ]  17%    Finish in: 00:00:43
# 2026-07-22 02:46:43 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [=>        ]  18%    Finish in: 00:00:45
# 2026-07-22 02:46:44 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [=>        ]  19%    Finish in: 00:00:46
# 2026-07-22 02:46:45 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:46:45 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:46:45 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [==>       ]  20%    Finish in: 00:00:43
# 2026-07-22 02:46:45 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:46:46 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:46:46 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [==>       ]  21%    Finish in: 00:00:45
# 2026-07-22 02:46:46 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [==>       ]  22%    Finish in: 00:00:42
# 2026-07-22 02:46:46 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:46:47 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:46:47 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [==>       ]  28%    Finish in: 00:00:38
# 2026-07-22 02:46:49 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:46:49 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [==>       ]  29%    Finish in: 00:00:36
# 2026-07-22 02:46:49 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:46:50 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [===>      ]  32%    Finish in: 00:00:36
# 2026-07-22 02:46:51 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:46:51 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [===>      ]  33%    Finish in: 00:00:34
# 2026-07-22 02:46:51 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:46:52 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [===>      ]  34%    Finish in: 00:00:34
# 2026-07-22 02:46:52 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [===>      ]  35%    Finish in: 00:00:33
# 2026-07-22 02:46:53 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:46:53 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:46:53 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [===>      ]  36%    Finish in: 00:00:33
# 2026-07-22 02:46:53 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:46:54 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [===>      ]  37%    Finish in: 00:00:34
# 2026-07-22 02:46:54 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [===>      ]  39%    Finish in: 00:00:32
# 2026-07-22 02:46:55 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [====>     ]  41%    Finish in: 00:00:31
# 2026-07-22 02:46:56 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [====>     ]  42%    Finish in: 00:00:31
# 2026-07-22 02:46:57 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:46:57 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:46:57 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [====>     ]  43%    Finish in: 00:00:30
# 2026-07-22 02:46:57 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [====>     ]  45%    Finish in: 00:00:29
# 2026-07-22 02:46:58 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [====>     ]  47%    Finish in: 00:00:28
# 2026-07-22 02:46:59 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:46:59 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:46:59 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [====>     ]  48%    Finish in: 00:00:27
# 2026-07-22 02:47:00 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:47:00 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [====>     ]  49%    Finish in: 00:00:27
# 2026-07-22 02:47:00 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:47:00 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:47:00 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:47:01 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [=====>    ]  53%    Finish in: 00:00:25
# 2026-07-22 02:47:03 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:47:03 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [=====>    ]  54%    Finish in: 00:00:24
# 2026-07-22 02:47:03 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:47:03 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:47:03 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:47:04 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:47:04 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [=====>    ]  56%    Finish in: 00:00:23
# 2026-07-22 02:47:05 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [=====>    ]  57%    Finish in: 00:00:23
# 2026-07-22 02:47:05 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:47:05 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [=====>    ]  59%    Finish in: 00:00:22
# 2026-07-22 02:47:06 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:47:06 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [======>   ]  61%    Finish in: 00:00:21
# 2026-07-22 02:47:07 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:47:07 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [======>   ]  63%    Finish in: 00:00:19
# 2026-07-22 02:47:09 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [======>   ]  65%    Finish in: 00:00:19
# 2026-07-22 02:47:10 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [======>   ]  66%    Finish in: 00:00:18
# 2026-07-22 02:47:10 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [======>   ]  68%    Finish in: 00:00:17
# 2026-07-22 02:47:11 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [=======>  ]  70%    Finish in: 00:00:16
# 2026-07-22 02:47:12 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:47:12 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:47:12 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:47:13 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [=======>  ]  71%    Finish in: 00:00:15
# 2026-07-22 02:47:13 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:47:13 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:47:13 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:47:13 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [=======>  ]  72%    Finish in: 00:00:15
# 2026-07-22 02:47:14 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [=======>  ]  73%    Finish in: 00:00:14
# 2026-07-22 02:47:14 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [=======>  ]  74%    Finish in: 00:00:14
# 2026-07-22 02:47:15 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:47:15 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [=======>  ]  75%    Finish in: 00:00:13
# 2026-07-22 02:47:15 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:47:16 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [=======>  ]  76%    Finish in: 00:00:13
# 2026-07-22 02:47:16 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:47:16 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [=======>  ]  77%    Finish in: 00:00:12
# 2026-07-22 02:47:17 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:47:17 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [=======>  ]  79%    Finish in: 00:00:11
# 2026-07-22 02:47:17 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [========> ]  82%    Finish in: 00:00:09
# 2026-07-22 02:47:19 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [========> ]  83%    Finish in: 00:00:09
# 2026-07-22 02:47:20 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:47:20 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [========> ]  85%    Finish in: 00:00:08
# 2026-07-22 02:47:21 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:47:21 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:47:21 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [========> ]  86%    Finish in: 00:00:07
# 2026-07-22 02:47:21 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:47:21 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [========> ]  87%    Finish in: 00:00:07
# 2026-07-22 02:47:22 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:47:22 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [========> ]  89%    Finish in: 00:00:06
# 2026-07-22 02:47:23 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [=========>]  90%    Finish in: 00:00:05
# 2026-07-22 02:47:23 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [=========>]  91%    Finish in: 00:00:04
# 2026-07-22 02:47:24 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:47:25 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [=========>]  92%    Finish in: 00:00:04
# 2026-07-22 02:47:25 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:47:26 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [=========>]  93%    Finish in: 00:00:03
# 2026-07-22 02:47:26 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:47:26 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [=========>]  94%    Finish in: 00:00:03
# 2026-07-22 02:47:26 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:47:27 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [=========>]  95%    Finish in: 00:00:02
# 2026-07-22 02:47:27 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [=========>]  96%    Finish in: 00:00:02
# 2026-07-22 02:47:27 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:47:28 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:47:28 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [=========>]  98%    Finish in: 00:00:01
# 2026-07-22 02:47:28 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:47:28 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:47:29 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-22 02:47:29 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Wed Jul 22 02:46:34 2026 : [ Finished ] 100%    Needed: 00:00:56  - Finished at Wed Jul 22 02:47:30 2026

# %% [markdown]
# ## Plotting
#
# We will now plot the spectrum of photons arriving at Earth.
# Note that whenever thinning is used, the weight column has to be enabled and the weights must be accounted for in the analysis.

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt('cascade_1d.txt', comments = '#')
energy = data[:, 2] # energies in eV
weight = data[:, 5]

bins = np.logspace(10, 15, 26, endpoint = True)
y, edges = np.histogram(energy , bins = bins, weights = weight)
x = edges[:-1] + ((edges[1:] - edges[:-1]) / 2.)
y *= x 
plt.xlim(1e10, 1e14)
plt.plot(x, y)
plt.xscale('log')
plt.yscale('log')
plt.ylabel('$E^2 dN/dE$ [arb. u.]')
plt.xlabel('E [eV]')
plt.show()

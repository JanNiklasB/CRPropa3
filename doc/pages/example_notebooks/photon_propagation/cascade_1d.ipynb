# %% [markdown]
# # Electromagnetic cascade example
#
# This is a simple 1D example of gamma-ray propagation over cosmological distances.
# Note that only pair production and inverse Compton scattering are relevant for the energy range of this example.
# Moreover, the radio background is negligible for the energy range below PeV.

# %%
from crpropa import *

dsrc = redshift2ComovingDistance(0.14)

electrons = True
photons = True

thinning = 0.90 # if 0, no thinning; speeds up the simulations considerably

cmb = CMB()
ebl = IRB_Gilmore12()
crb = URB_Nitu21()

sim = ModuleList()
sim.add(SimplePropagation())
sim.add(Redshift())
sim.add(EMPairProduction(cmb, electrons, thinning))
sim.add(EMPairProduction(ebl, electrons, thinning))
# sim.add(EMPairProduction(crb, electrons, thinning)) 
# sim.add(EMDoublePairProduction(cmb, electrons, thinning))
# sim.add(EMDoublePairProduction(ebl, electrons, thinning))
# sim.add(EMDoublePairProduction(crb, electrons, thinning))
sim.add(EMInverseComptonScattering(cmb, photons, thinning))
sim.add(EMInverseComptonScattering(ebl, photons, thinning))
# sim.add(EMInverseComptonScattering(crb, photons, thinning))
# sim.add(EMTripletPairProduction(cmb, electrons, thinning))
# sim.add(EMTripletPairProduction(ebl, electrons, thinning))
# sim.add(EMTripletPairProduction(crb, electrons, thinning))
sim.add(MinimumEnergy(10 * GeV))

obs = Observer()
obs.add(Observer1D())
obs.add(ObserverElectronVeto()) # we are only interested in photons
output = TextOutput('cascade_1d.txt', Output.Event1D)
output.setEnergyScale(eV)
output.enable(output.WeightColumn) # this is required if thinning > 0
output.disable(output.CandidateTagColumn) # not needed in this analysis
obs.onDetection(output)

source = Source()
source.add(SourcePosition(Vector3d(dsrc, 0, 0)))
source.add(SourceRedshift1D())
source.add(SourceParticleType(22))
source.add(SourcePowerLawSpectrum(10 * GeV, 10 * TeV, -1.5)) # intrinsic source spectrum
# source.add(SourceEnergy(20 * TeV)) # a monochromatic intrinsic spectrum

sim.add(obs)
sim.setShowProgress(True)
sim.run(source, 10000, True)

output.close()
# Out:
# crpropa::ModuleList: Number of Threads: 32
# Run ModuleList
#   Started Tue Jul 21 23:23:29 2026 : [>         ]   2%    Finish in: 00:00:00
# 2026-07-21 23:23:29 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:23:29 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:23:30 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:23:30 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [>         ]   3%    Finish in: 00:00:32
# 2026-07-21 23:23:30 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:23:30 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [>         ]   6%    Finish in: 00:00:31
# 2026-07-21 23:23:31 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [>         ]   7%    Finish in: 00:00:26
# 2026-07-21 23:23:32 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [>         ]   8%    Finish in: 00:00:45
# 2026-07-21 23:23:33 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:23:33 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [>         ]   9%    Finish in: 00:00:40
# 2026-07-21 23:23:33 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:23:33 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:23:34 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [=>        ]  10%    Finish in: 00:00:36
# 2026-07-21 23:23:34 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [=>        ]  11%    Finish in: 00:00:40
# 2026-07-21 23:23:34 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:23:35 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [=>        ]  13%    Finish in: 00:00:40
# 2026-07-21 23:23:35 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:23:35 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [=>        ]  15%    Finish in: 00:00:33
# 2026-07-21 23:23:35 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:23:36 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:23:36 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [=>        ]  16%    Finish in: 00:00:36
# 2026-07-21 23:23:36 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:23:36 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:23:37 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:23:37 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [=>        ]  17%    Finish in: 00:00:39
# 2026-07-21 23:23:37 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [=>        ]  18%    Finish in: 00:00:40
# 2026-07-21 23:23:38 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [==>       ]  23%    Finish in: 00:00:36
# 2026-07-21 23:23:40 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:23:41 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [==>       ]  24%    Finish in: 00:00:37
# 2026-07-21 23:23:41 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [==>       ]  25%    Finish in: 00:00:35
# 2026-07-21 23:23:42 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [==>       ]  26%    Finish in: 00:00:36
# 2026-07-21 23:23:42 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [==>       ]  27%    Finish in: 00:00:35
# 2026-07-21 23:23:43 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [==>       ]  28%    Finish in: 00:00:35
# 2026-07-21 23:23:43 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [==>       ]  29%    Finish in: 00:00:36
# 2026-07-21 23:23:44 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:23:44 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:23:44 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [===>      ]  33%    Finish in: 00:00:32
# 2026-07-21 23:23:46 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [===>      ]  34%    Finish in: 00:00:32
# 2026-07-21 23:23:46 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [===>      ]  36%    Finish in: 00:00:31
# 2026-07-21 23:23:47 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:23:47 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:23:48 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:23:48 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [===>      ]  37%    Finish in: 00:00:32
# 2026-07-21 23:23:48 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:23:48 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [===>      ]  38%    Finish in: 00:00:30
# 2026-07-21 23:23:48 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [===>      ]  39%    Finish in: 00:00:31
# 2026-07-21 23:23:49 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:23:49 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:23:49 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [====>     ]  40%    Finish in: 00:00:29
# 2026-07-21 23:23:50 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:23:50 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [====>     ]  42%    Finish in: 00:00:28
# 2026-07-21 23:23:50 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:23:50 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [====>     ]  43%    Finish in: 00:00:27
# 2026-07-21 23:23:50 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:23:51 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [====>     ]  44%    Finish in: 00:00:27
# 2026-07-21 23:23:51 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [====>     ]  45%    Finish in: 00:00:28
# 2026-07-21 23:23:52 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [====>     ]  47%    Finish in: 00:00:27
# 2026-07-21 23:23:53 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [====>     ]  49%    Finish in: 00:00:26
# 2026-07-21 23:23:54 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:23:54 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:23:54 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [=====>    ]  50%    Finish in: 00:00:24
# 2026-07-21 23:23:55 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [=====>    ]  51%    Finish in: 00:00:24
# 2026-07-21 23:23:55 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:23:55 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:23:55 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [=====>    ]  55%    Finish in: 00:00:22
# 2026-07-21 23:23:58 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [=====>    ]  56%    Finish in: 00:00:22
# 2026-07-21 23:23:58 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:23:58 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [=====>    ]  59%    Finish in: 00:00:20
# 2026-07-21 23:24:00 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:24:00 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [======>   ]  61%    Finish in: 00:00:19
# 2026-07-21 23:24:00 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:24:01 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [======>   ]  62%    Finish in: 00:00:19
# 2026-07-21 23:24:01 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [======>   ]  63%    Finish in: 00:00:19
# 2026-07-21 23:24:02 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [======>   ]  65%    Finish in: 00:00:18
# 2026-07-21 23:24:03 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [======>   ]  66%    Finish in: 00:00:18
# 2026-07-21 23:24:04 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:24:04 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [======>   ]  67%    Finish in: 00:00:17
# 2026-07-21 23:24:05 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:24:05 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [======>   ]  68%    Finish in: 00:00:16
# 2026-07-21 23:24:05 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [=======>  ]  71%    Finish in: 00:00:15
# 2026-07-21 23:24:07 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:24:07 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [=======>  ]  73%    Finish in: 00:00:14
# 2026-07-21 23:24:09 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [=======>  ]  75%    Finish in: 00:00:13
# 2026-07-21 23:24:10 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:24:10 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [=======>  ]  76%    Finish in: 00:00:12
# 2026-07-21 23:24:10 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [=======>  ]  77%    Finish in: 00:00:12
# 2026-07-21 23:24:11 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [=======>  ]  79%    Finish in: 00:00:11
# 2026-07-21 23:24:12 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:24:12 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:24:12 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:24:12 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [========> ]  80%    Finish in: 00:00:10
# 2026-07-21 23:24:13 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [========> ]  82%    Finish in: 00:00:09
# 2026-07-21 23:24:14 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:24:14 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [========> ]  84%    Finish in: 00:00:08
# 2026-07-21 23:24:15 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:24:15 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:24:15 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [========> ]  85%    Finish in: 00:00:08
# 2026-07-21 23:24:16 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [========> ]  86%    Finish in: 00:00:07
# 2026-07-21 23:24:16 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:24:16 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [========> ]  87%    Finish in: 00:00:07
# 2026-07-21 23:24:17 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [=========>]  90%    Finish in: 00:00:05
# 2026-07-21 23:24:18 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:24:19 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:24:19 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:24:19 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [=========>]  91%    Finish in: 00:00:04
# 2026-07-21 23:24:19 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [=========>]  92%    Finish in: 00:00:04
# 2026-07-21 23:24:20 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:24:20 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:24:21 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [=========>]  93%    Finish in: 00:00:03
# 2026-07-21 23:24:21 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [=========>]  94%    Finish in: 00:00:03
# 2026-07-21 23:24:22 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:24:22 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [=========>]  95%    Finish in: 00:00:02
# 2026-07-21 23:24:22 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
# 2026-07-21 23:24:22 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [=========>]  96%    Finish in: 00:00:02
# 2026-07-21 23:24:23 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [=========>]  97%    Finish in: 00:00:01
# 2026-07-21 23:24:24 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [=========>]  98%    Finish in: 00:00:01
# 2026-07-21 23:24:24 [WARNING] EMPaiProduction: Sampled s value is the lowest tabulated value, which is not physical. The index j will be set to 1 to avoid division by zero.
#   Started Tue Jul 21 23:23:29 2026 : [ Finished ] 100%    Needed: 00:00:57  - Finished at Tue Jul 21 23:24:26 2026

# %% [markdown]
# ## Plotting
#
# We will now plot the spectrum of photons arriving at Earth.
# Note that whenever thinning is used, the weight column has to be enabled and the weights must be accounted for in the analysis.

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt('cascade_1d.txt', comments = '#')
energy = data[:, 2] # energies in eV
weight = data[:, 5]

bins = np.logspace(10, 15, 26, endpoint = True)
y, edges = np.histogram(energy , bins = bins, weights = weight)
x = edges[:-1] + ((edges[1:] - edges[:-1]) / 2.)
y *= x 
plt.xlim(1e10, 1e14)
plt.plot(x, y)
plt.xscale('log')
plt.yscale('log')
plt.ylabel('$E^2 dN/dE$ [arb. u.]')
plt.xlabel('E [eV]')
plt.show()

# %% [markdown]
# # 4D Simulation
#
# The following is a simple 4D simulation where cosmic rays are emitted by a source at a specified spatial position at a specified time-point. A cosmic ray is detected if it arrives at the observer position within a specified time window.
#
# **Note:** In CRPropa, time is always expressed in terms of redshift $z$, whereas positions are always expressed in terms of comoving coordinates as Cartesian 3-vectors.
#
# ### Simulation setup
# The simulation setup is that of a 3D simulation with a few additions:
# 1. We add a source property for the redshift at emission. This can be either ```SourceRedshift```, ```SourceUniformRedshift``` or ```SourceRedshiftEvolution```.
# 2. The simulation module ```FutureRedshift``` implements adiabatic energy loss and updates the redshift. In contrast to ```Redshift``` it allows particles to be propagated into the future $z < 0$ which enables faster convergence for finite observation windows.
# 3. The observer feature ```ObserverRedshiftWindow``` specifies a time window $z_\mathrm{min} < z < z_\mathrm{max}$ in which particles are detected if they hit the observer. Note that this can also be done after the simulation by cutting on the redshifts at observation. For this we also output the current redshift at observation.
# 4. A minimum redshift is defined via MinimumRedshift which we set to the lower bound of the observer time window.
#
# ### Periodic boundaries
# Due to the additional time dimension, particles are detected much less often. In order to increase the otherwhise horrible simulation efficiency, a ```PeriodicBox``` is defined: Particles that leave this simulation volume, enter again from the opposite side and their source position is moved accordingly.
# As a result the periodic boundaries keep the particles close to the observer and therefore increase the chance of detection. A careful setup is required however:
# 1. Sources should only be defined inside the volume as sources outside are filled up by the periodic conditions.
# 2. The magnetic field at the boundaries should be periodic as well. This is the case for ```initTurbulence``` as long as the simulation volume coincides with (multiples of) the magnetic field grid.
#
# ### Source positions
# In the example below, a single source is defined. For specifying multiple identical discrete sources ```SourceMultiplePositions``` can be used. Multiple non-identical sources can be added to a ```SourceList```. For continous source distributions ```SourceUniformSphere```, ```SourceUniformBox``` and ```SourceUniformCylinder``` can be used. ```SourceDensityGrid``` allows to specify a source distribution via a 3D grid.

# %% [markdown]
# ### Note:
# This simulation may take **several** minutes.

# %%
from crpropa import *


# set up random turbulent field
Brms = 1 * nG
lMin = 60 * kpc
lMax = 800 * kpc
sIndex = 5./3.
turbSpectrum = SimpleTurbulenceSpectrum(Brms, lMin, lMax, sIndex)
gridprops = GridProperties(Vector3d(0), 256, 30 * kpc)
Bfield = SimpleGridTurbulence(turbSpectrum, gridprops, 42)

# simulation setup
sim = ModuleList()
sim.add(PropagationCK(Bfield))
sim.add(FutureRedshift())
#sim.add(FutureRedshift()) # Switch back to FutureRedshift when PR #416 is merged
sim.add(Redshift())
sim.add(PhotoPionProduction(CMB()))
sim.add(PhotoPionProduction(IRB_Kneiske04()))
sim.add(PhotoDisintegration(CMB()))
sim.add(PhotoDisintegration(IRB_Kneiske04()))
sim.add(ElectronPairProduction(CMB()))
sim.add(ElectronPairProduction(IRB_Kneiske04()))
sim.add(NuclearDecay())
sim.add(MinimumEnergy(1 * EeV))
#sim.add(MinimumRedshift(-0.1)) # Switch back to z_min=-0.1 when PR #416 is merged
sim.add(MinimumRedshift(0.))


# periodic boundaries
extent = 256 * 30 * kpc  # size of the magnetic field grid
sim.add(PeriodicBox(Vector3d(-extent), Vector3d(2 * extent)))

# define the observer
obs = Observer()
obs.add(ObserverSurface( Sphere(Vector3d(0.), 0.5 * Mpc)))
obs.add(ObserverRedshiftWindow(-0.1, 0.1))
output = TextOutput('output.txt', Output.Event3D)
output.enable(output.RedshiftColumn)
obs.onDetection(output)
sim.add(obs)

# define the source(s)
source = Source()
source.add(SourcePosition(Vector3d(10, 0, 0) * Mpc))
source.add(SourceIsotropicEmission())
source.add(SourceParticleType(nucleusId(1, 1)))
source.add(SourcePowerLawSpectrum(1 * EeV, 200 * EeV, -1))
source.add(SourceRedshiftEvolution(1.5, 0.001, 3))

# run simulation
sim.setShowProgress(True)
sim.run(source, 10000)
output.close()
# Out:
# crpropa::ModuleList: Number of Threads: 32
# Run ModuleList
#   Started Tue Jul 21 20:37:40 2026 : [>         ]   1%    Finish in: 00:01:38
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. 2026-07-21 20:37:40 [WARNING] Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 2026-07-21 20:37:40 [WARNING] 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 2026-07-21 20:37:40 [WARNING] 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 2026-07-21 20:37:40 [WARNING] 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 2026-07-21 20:37:40 [WARNING] 1. Approximated value used A * amu - Z * m_e instead.2026-07-21 20:37:40 2026-07-21 20:37:40 [WARNINGnuclearMass: nuclear mass not found in the mass table for
# [WARNING] ] nuclearMass: nuclear mass not found in the mass table for 2026-07-21 20:37:40 [WARNINGA = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# ] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.2026-07-21 20:37:40 [WARNING]
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = 1. . Approximated value used A * amu - Z * m_e instead.
# Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING2026-07-21 20:37:40 [] nuclearMass: nuclear mass not found in the mass table for A = WARNING] 1, Z = 1nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [. Approximated value used A * amu - Z * m_e instead.WARNING]
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 2026-07-21 20:37:40 [[WARNING] WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 12026-07-21 20:37:40 [WARNING] . Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 12026-07-21 20:37:40 2026-07-21 20:37:40 [, Z = 2026-07-21 20:37:40 1. [[Approximated value used A * amu - Z * m_e instead.WARNINGWARNING] ] WARNING]
# nuclearMass: nuclear mass not found in the mass table for A = 2026-07-21 20:37:40 [WARNING] 1, Z = 1. Approximated value used A * amu - Z * m_e instead.nuclearMass: nuclear mass not found in the mass table for
# 2026-07-21 20:37:40 [A = 1, Z = 1. WARNING] Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for 2026-07-21 20:37:40 A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# [nuclearMass: nuclear mass not found in the mass table for 2026-07-21 20:37:40 A = WARNING] nuclearMass: nuclear mass not found in the mass table for A = [nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. WARNING] Approximated value used A * amu - Z * m_e instead.
# 1, Z = 1. 2026-07-21 20:37:40 [WARNING] Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for 2026-07-21 20:37:40 A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# [1, Z = 1WARNING] . Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 2026-07-21 20:37:40 2026-07-21 20:37:40 [1, Z = [WARNING1] WARNING] . Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for 2026-07-21 20:37:40 [WARNING] A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.nuclearMass: nuclear mass not found in the mass table for
# A = 1, Z = 2026-07-21 20:37:40 [WARNING] 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for 2026-07-21 20:37:40 [WARNING] A = 1, Z = 1nuclearMass: nuclear mass not found in the mass table for A = 1nuclearMass: nuclear mass not found in the mass table for . Approximated value used A * amu - Z * m_e instead.
# , Z = 1. Approximated value used A * amu - Z * m_e instead.A = 1, Z = 1.
# Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 2026-07-21 20:37:40 [WARNING] 1. 2026-07-21 20:37:40 [WARNING] Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.nuclearMass: nuclear mass not found in the mass table for
# 2026-07-21 20:37:40 2026-07-21 20:37:40 A = [2026-07-21 20:37:40 [[WARNING] 1, Z = WARNING] 2026-07-21 20:37:40 WARNING] [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 11nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for A = A = A = . 11, Z = , Z = 11Approximated value used A * amu - Z * m_e instead..
# Approximated value used A * amu - Z * m_e instead.
# 12026-07-21 20:37:40 [WARNING] , Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. 2026-07-21 20:37:40 [Approximated value used A * amu - Z * m_e instead.WARNING] nuclearMass: nuclear mass not found in the mass table for
# [2026-07-21 20:37:40 [WARNING] A = WARNING] 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. nuclearMass: nuclear mass not found in the mass table for A = . 1Approximated value used A * amu - Z * m_e instead.
# Approximated value used A * amu - Z * m_e instead.
# , Z = 1. Approximated value used A * amu - Z * m_e instead.
# , Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 2026-07-21 20:37:40 2026-07-21 20:37:40 [WARNING1[. 2026-07-21 20:37:40 [] Approximated value used A * amu - Z * m_e instead.
# WARNING2026-07-21 20:37:40 ] WARNINGnuclearMass: nuclear mass not found in the mass table for [2026-07-21 20:37:40 WARNING] [WARNINGnuclearMass: nuclear mass not found in the mass table for ] nuclearMass: nuclear mass not found in the mass table for A = ] nuclearMass: nuclear mass not found in the mass table for 1nuclearMass: nuclear mass not found in the mass table for A = A = 1, Z = A = 11, Z = A = 1. , Z = 1. Approximated value used A * amu - Z * m_e instead.Approximated value used A * amu - Z * m_e instead.1
# , Z =
# 1. Approximated value used A * amu - Z * m_e instead.2026-07-21 20:37:40
# 2026-07-21 20:37:40 1[WARNING[2026-07-21 20:37:40 [WARNING] ] WARNING] . Approximated value used A * amu - Z * m_e instead.
# , Z = 12026-07-21 20:37:40 [WARNING] . Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 2026-07-21 20:37:40 [WARNING] 1, Z = 1. nuclearMass: nuclear mass not found in the mass table for A = 1nuclearMass: nuclear mass not found in the mass table for , Z = nuclearMass: nuclear mass not found in the mass table for 1A = A = 1Approximated value used A * amu - Z * m_e instead.
# . 1nuclearMass: nuclear mass not found in the mass table for A = , Z = 1, Z = 1Approximated value used A * amu - Z * m_e instead.1
# . Approximated value used A * amu - Z * m_e instead.
# , Z = 1. Approximated value used A * amu - Z * m_e instead.
# . Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 2026-07-21 20:37:40 [[2026-07-21 20:37:40 WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# [WARNING] nuclearMass: nuclear mass not found in the mass table for 2026-07-21 20:37:40 [WARNING] WARNING] A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for 2026-07-21 20:37:40 A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 12026-07-21 20:37:40 . Approximated value used A * amu - Z * m_e instead.
# [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for 2026-07-21 20:37:40 [WARNING] A = 1, Z = 1nuclearMass: nuclear mass not found in the mass table for . 1Approximated value used A * amu - Z * m_e instead.A = 1
# , Z = 1. Approximated value used A * amu - Z * m_e instead.
# , Z = 12026-07-21 20:37:40 2026-07-21 20:37:40 [WARNING] . [WARNING] Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 2026-07-21 20:37:40 [WARNING] 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.2026-07-21 20:37:40 [WARNING] 2026-07-21 20:37:40 2026-07-21 20:37:40 [nuclearMass: nuclear mass not found in the mass table for WARNING
# [WARNINGA = ] 12026-07-21 20:37:40 , Z = ] [WARNING] 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 2026-07-21 20:37:40 1[WARNING, Z = 1. Approximated value used A * amu - Z * m_e instead.
# ] nuclearMass: nuclear mass not found in the mass table for A = 12026-07-21 20:37:40 [WARNING] , Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 2026-07-21 20:37:40 2026-07-21 20:37:40 [1[WARNING, Z = WARNING] nuclearMass: nuclear mass not found in the mass table for ] 1. Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = 1. 2026-07-21 20:37:40 [WARNING] Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for 2026-07-21 20:37:40 [WARNING] A = 1, Z = 1. nuclearMass: nuclear mass not found in the mass table for A = 1Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = , Z = 1nuclearMass: nuclear mass not found in the mass table for 1A = 1, Z = . Approximated value used A * amu - Z * m_e instead.
# . Approximated value used A * amu - Z * m_e instead.
# 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [2026-07-21 20:37:40 WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for 2026-07-21 20:37:40 [WARNING2026-07-21 20:37:40 A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for [WARNING2026-07-21 20:37:40 ] [] WARNINGA = 2026-07-21 20:37:40 [WARNING] ] 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for 1A = nuclearMass: nuclear mass not found in the mass table for A = 1A = 1, Z = 1, Z = , Z = 11. Approximated value used A * amu - Z * m_e instead.
# , Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 . Approximated value used A * amu - Z * m_e instead.
# 1. Approximated value used A * amu - Z * m_e instead.2026-07-21 20:37:40 [
# WARNING[WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. ] 2026-07-21 20:37:40 [WARNINGApproximated value used A * amu - Z * m_e instead.
# ] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1nuclearMass: nuclear mass not found in the mass table for A = 1, Z = . Approximated value used A * amu - Z * m_e instead.
# 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 2026-07-21 20:37:40 [[WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1WARNING] . Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 2026-07-21 20:37:40 2026-07-21 20:37:40 [[[2026-07-21 20:37:40 WARNING] nuclearMass: nuclear mass not found in the mass table for A = WARNING[1WARNING] ] WARNING] nuclearMass: nuclear mass not found in the mass table for A = , Z = nuclearMass: nuclear mass not found in the mass table for 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.2026-07-21 20:37:40 1
# [WARNING2026-07-21 20:37:40 [WARNING] , Z = 1A = ] . Approximated value used A * amu - Z * m_e instead.
# 1, Z = 1. Approximated value used A * amu - Z * m_e instead.nuclearMass: nuclear mass not found in the mass table for
# 2026-07-21 20:37:40 A = 1[WARNING2026-07-21 20:37:40 [] WARNING] , Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 12026-07-21 20:37:40 [WARNING2026-07-21 20:37:40 [] WARNING] , Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. . Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1Approximated value used A * amu - Z * m_e instead.
# . Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. nuclearMass: nuclear mass not found in the mass table for A = 1Approximated value used A * amu - Z * m_e instead.
# , Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for 2026-07-21 20:37:40 [WARNING] A = 2026-07-21 20:37:40 [WARNING1, Z = 1. Approximated value used A * amu - Z * m_e instead.2026-07-21 20:37:40 [WARNING]
# nuclearMass: nuclear mass not found in the mass table for 2026-07-21 20:37:40 [WARNING] A = ] 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for 2026-07-21 20:37:40 [WARNING] A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 2026-07-21 20:37:40 [WARNING] 1. Approximated value used A * amu - Z * m_e instead.nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
#
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] 2026-07-21 20:37:40 [WARNINGnuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1] . Approximated value used A * amu - Z * m_e instead.2026-07-21 20:37:40 nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.[WARNING]
# nuclearMass: nuclear mass not found in the mass table for
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 2026-07-21 20:37:40 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1[, Z = [WARNINGWARNING] ] 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 nuclearMass: nuclear mass not found in the mass table for A = [12026-07-21 20:37:40 WARNING] 2026-07-21 20:37:40 [WARNING] [WARNING] , Z = nuclearMass: nuclear mass not found in the mass table for 1nuclearMass: nuclear mass not found in the mass table for . nuclearMass: nuclear mass not found in the mass table for A = A = 1, Z = nuclearMass: nuclear mass not found in the mass table for A = A = 111, Z = 11, Z = 1. . Approximated value used A * amu - Z * m_e instead..
# 2026-07-21 20:37:40 [Approximated value used A * amu - Z * m_e instead.
# WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. 2026-07-21 20:37:40 [WARNING] Approximated value used A * amu - Z * m_e instead.
# , Z = 1. Approximated value used A * amu - Z * m_e instead.
# Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# ] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] 2026-07-21 20:37:40 [WARNING2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for ] A = 1nuclearMass: nuclear mass not found in the mass table for , Z = nuclearMass: nuclear mass not found in the mass table for 12026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 2026-07-21 20:37:40 1[WARNING] , Z = 1. Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.A =
# 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for 2026-07-21 20:37:40 [WARNING] A = 1, Z = . Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:40 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1[WARNING] , Z = 2026-07-21 20:37:41 [12026-07-21 20:37:41 [WARNING] . Approximated value used A * amu - Z * m_e instead.WARNING
# nuclearMass: nuclear mass not found in the mass table for ] A = 2026-07-21 20:37:41 [WARNING] 1nuclearMass: nuclear mass not found in the mass table for A = 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 2026-07-21 20:37:41 [WARNING1] , Z = 1. Approximated value used A * amu - Z * m_e instead.
# , Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 2026-07-21 20:37:41 [2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for [WARNING] 2026-07-21 20:37:41 [WARNING] WARNING] 2026-07-21 20:37:41 [WARNING] A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1nuclearMass: nuclear mass not found in the mass table for , Z = 1. Approximated value used A * amu - Z * m_e instead.A =
# 12026-07-21 20:37:41 [nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.WARNING]
# , Z = nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 0. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] 2026-07-21 20:37:41 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = [WARNING] 12026-07-21 20:37:41 [WARNING] , Z = 1. 2026-07-21 20:37:41 [WARNING] Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for 2026-07-21 20:37:41 [WARNING] A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 2026-07-21 20:37:41 2026-07-21 20:37:41 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# [WARNING] nuclearMass: nuclear mass not found in the mass table for [2026-07-21 20:37:41 [WARNINGWARNING] ] A = 2026-07-21 20:37:41 2026-07-21 20:37:41 1[WARNING] nuclearMass: nuclear mass not found in the mass table for [A = 2026-07-21 20:37:41 [WARNING2026-07-21 20:37:41 [WARNINGWARNING1] ] , Z = ] 1nuclearMass: nuclear mass not found in the mass table for . A = Approximated value used A * amu - Z * m_e instead.1
# , Z = 1nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for A = nuclearMass: nuclear mass not found in the mass table for . A = Approximated value used A * amu - Z * m_e instead.nuclearMass: nuclear mass not found in the mass table for
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = A = 1, Z = 1. 1A = 1, Z = 1. 1Approximated value used A * amu - Z * m_e instead..
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for Approximated value used A * amu - Z * m_e instead.A =
# 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# , Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1Approximated value used A * amu - Z * m_e instead.
# , Z = 1. Approximated value used A * amu - Z * m_e instead.
# , Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 2026-07-21 20:37:41 [WARNING[WARNING] ] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 2026-07-21 20:37:41 2026-07-21 20:37:41 2026-07-21 20:37:41 [[[WARNING] [WARNING] WARNINGnuclearMass: nuclear mass not found in the mass table for ] nuclearMass: nuclear mass not found in the mass table for WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 2026-07-21 20:37:41 [WARNING] 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# A = 2026-07-21 20:37:41 [WARNING] 1, Z = 1nuclearMass: nuclear mass not found in the mass table for A = 1nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# . 2026-07-21 20:37:41 Approximated value used A * amu - Z * m_e instead.
# , Z = 1[WARNING] . Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 12026-07-21 20:37:41 [, Z = 1WARNING] 2026-07-21 20:37:41 [WARNING] . Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# , Z = 2026-07-21 20:37:41 2026-07-21 20:37:41 [WARNING12026-07-21 20:37:41 . ] [WARNING] Approximated value used A * amu - Z * m_e instead.[WARNING2026-07-21 20:37:41 [WARNING] ]
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1Approximated value used A * amu - Z * m_e instead.
# , Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [2026-07-21 20:37:41 WARNING] nuclearMass: nuclear mass not found in the mass table for [2026-07-21 20:37:41 [WARNING] WARNING] 2026-07-21 20:37:41 [WARNING] A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. , Z = nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 1. Approximated value used A * amu - Z * m_e instead.Approximated value used A * amu - Z * m_e instead.
#
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [2026-07-21 20:37:41 WARNING2026-07-21 20:37:41 [[] 2026-07-21 20:37:41 [WARNINGWARNING] WARNINGnuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for ] 2026-07-21 20:37:41 [A = ] 2026-07-21 20:37:41 [WARNING1WARNING] ] , Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [A = WARNING1, Z = 1] . Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for 2026-07-21 20:37:41 [WARNING] A = 1, Z = 12026-07-21 20:37:41 [WARNING] . Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. 2026-07-21 20:37:41 [nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. WARNING] Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. 2026-07-21 20:37:41 [WARNING] Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 nuclearMass: nuclear mass not found in the mass table for [WARNINGA = 1, Z = Approximated value used A * amu - Z * m_e instead.]
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 11. Approximated value used A * amu - Z * m_e instead.. Approximated value used A * amu - Z * m_e instead.
#
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. [WARNING] Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 12026-07-21 20:37:41 [WARNING] , Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. 2026-07-21 20:37:41 2026-07-21 20:37:41 2026-07-21 20:37:41 [[Approximated value used A * amu - Z * m_e instead.WARNING2026-07-21 20:37:41 [WARNING] ]
# WARNINGnuclearMass: nuclear mass not found in the mass table for [WARNING] nuclearMass: nuclear mass not found in the mass table for A = ] 2026-07-21 20:37:41 [WARNING] 1, Z = A = 11nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for , Z = A = A = 1. , Z = 11Approximated value used A * amu - Z * m_e instead..
# , Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 12026-07-21 20:37:41 2026-07-21 20:37:41 [[WARNINGWARNING[. ] WARNING] ] nuclearMass: nuclear mass not found in the mass table for Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.A =
# 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] 2026-07-21 20:37:41 nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# [WARNING2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = ] 1, Z = 1nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# . Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for 2026-07-21 20:37:41 [WARNING] A = 1nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# , Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 2026-07-21 20:37:41 2026-07-21 20:37:41 [WARNING] [1WARNING] , Z = 2026-07-21 20:37:41 2026-07-21 20:37:41 [WARNING2026-07-21 20:37:41 nuclearMass: nuclear mass not found in the mass table for [] [A = nuclearMass: nuclear mass not found in the mass table for A = WARNING] WARNING1] 11nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for A = , Z = 1, Z = , Z = . 1nuclearMass: nuclear mass not found in the mass table for . A = Approximated value used A * amu - Z * m_e instead.Approximated value used A * amu - Z * m_e instead.
#
# 2026-07-21 20:37:41 1. Approximated value used A * amu - Z * m_e instead.2026-07-21 20:37:41 A = [[
# WARNING] WARNING1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# ] nuclearMass: nuclear mass not found in the mass table for 2026-07-21 20:37:41 A = 1[WARNING, Z = 2026-07-21 20:37:41 1. [2026-07-21 20:37:41 WARNING] [WARNING] Approximated value used A * amu - Z * m_e instead.2026-07-21 20:37:41 ] 2026-07-21 20:37:41 [WARNING] [2026-07-21 20:37:41 nuclearMass: nuclear mass not found in the mass table for [2026-07-21 20:37:41 WARNINGA = ] 1[WARNING
# ] 2026-07-21 20:37:41 2026-07-21 20:37:41 [2026-07-21 20:37:41 WARNING] WARNINGnuclearMass: nuclear mass not found in the mass table for [[A = ] 1WARNING] nuclearMass: nuclear mass not found in the mass table for WARNINGA = ] nuclearMass: nuclear mass not found in the mass table for 12026-07-21 20:37:41 [, Z = 1WARNING] . Approximated value used A * amu - Z * m_e instead.
# 1. Approximated value used A * amu - Z * m_e instead.
# 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1nuclearMass: nuclear mass not found in the mass table for . Approximated value used A * amu - Z * m_e instead.
# , Z = 1. Approximated value used A * amu - Z * m_e instead.
# , Z = 1. Approximated value used A * amu - Z * m_e instead.
# A = 1nuclearMass: nuclear mass not found in the mass table for A = nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for A = A = 1A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# , Z = nuclearMass: nuclear mass not found in the mass table for 1, Z = 1. Approximated value used A * amu - Z * m_e instead., Z =
# 1. Approximated value used A * amu - Z * m_e instead.
# A = nuclearMass: nuclear mass not found in the mass table for 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = 11. Approximated value used A * amu - Z * m_e instead.
# ...
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = 1A = 1, Z = . . 1Approximated value used A * amu - Z * m_e instead..
# Approximated value used A * amu - Z * m_e instead.
# Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING2026-07-21 20:37:41 2026-07-21 20:37:41 [[2026-07-21 20:37:41 ] [WARNING2026-07-21 20:37:41 [WARNINGWARNINGWARNING] ] 2026-07-21 20:37:41 ] [WARNING] ] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] 2026-07-21 20:37:41 nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. [WARNING] Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1] , Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 2026-07-21 20:37:41 [12026-07-21 20:37:41 [WARNING] , Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 2026-07-21 20:37:41 1[WARNING] 2026-07-21 20:37:41 , Z = 1. Approximated value used A * amu - Z * m_e instead.
# WARNING] [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for A = 1, Z = A = 1, Z = 1. 1. Approximated value used A * amu - Z * m_e instead.
# . Approximated value used A * amu - Z * m_e instead.
# Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 12026-07-21 20:37:41 2026-07-21 20:37:41 . Approximated value used A * amu - Z * m_e instead.
# [2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 2026-07-21 20:37:41 [WARNING] 1[, Z = 1. Approximated value used A * amu - Z * m_e instead.
# WARNINGnuclearMass: nuclear mass not found in the mass table for 2026-07-21 20:37:41 A = 1WARNING] ] [WARNING] , Z = 1nuclearMass: nuclear mass not found in the mass table for . A = 1nuclearMass: nuclear mass not found in the mass table for Approximated value used A * amu - Z * m_e instead., Z =
# 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 12026-07-21 20:37:41 [, Z = 1. Approximated value used A * amu - Z * m_e instead.
# A = 2026-07-21 20:37:41 2026-07-21 20:37:41 WARNING1] [WARNING] [WARNING] , Z = 1. Approximated value used A * amu - Z * m_e instead.nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1.
# 2026-07-21 20:37:41 [WARNING] Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.nuclearMass: nuclear mass not found in the mass table for
# A = 1nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. 2026-07-21 20:37:41 [WARNING] Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 12026-07-21 20:37:41 [WARNING] . Approximated value used A * amu - Z * m_e instead.2026-07-21 20:37:41 nuclearMass: nuclear mass not found in the mass table for A = [
# 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 nuclearMass: nuclear mass not found in the mass table for A = 1, Z = , Z = 1. Approximated value used A * amu - Z * m_e instead.[1. Approximated value used A * amu - Z * m_e instead.
# WARNING]
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.2026-07-21 20:37:41 [WARNING]
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 2026-07-21 20:37:41 2026-07-21 20:37:41 1. Approximated value used A * amu - Z * m_e instead.
# [2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = [WARNING2026-07-21 20:37:41 [WARNING] WARNING] 2026-07-21 20:37:41 ] 1[WARNING] 2026-07-21 20:37:41 [WARNING] 2026-07-21 20:37:41 [WARNING] , Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 12026-07-21 20:37:41 [WARNING2026-07-21 20:37:41 ] [WARNING] , Z = 2026-07-21 20:37:41 1. Approximated value used A * amu - Z * m_e instead.[nuclearMass: nuclear mass not found in the mass table for WARNING] A =
# 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1nuclearMass: nuclear mass not found in the mass table for . nuclearMass: nuclear mass not found in the mass table for A = 1, Z = nuclearMass: nuclear mass not found in the mass table for A = A = 1, Z = nuclearMass: nuclear mass not found in the mass table for 1A = nuclearMass: nuclear mass not found in the mass table for 1A = . 11, Z = , Z = . 1Approximated value used A * amu - Z * m_e instead..
# Approximated value used A * amu - Z * m_e instead.
# Approximated value used A * amu - Z * m_e instead.
# 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 1. Approximated value used A * amu - Z * m_e instead.
# Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [2026-07-21 20:37:41 2026-07-21 20:37:41 2026-07-21 20:37:41 WARNING] nuclearMass: nuclear mass not found in the mass table for [[WARNING] WARNING] A = [1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = nuclearMass: nuclear mass not found in the mass table for WARNINGA = 2026-07-21 20:37:41 1[, Z = 1. Approximated value used A * amu - Z * m_e instead.] WARNING] 1
# . Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 12026-07-21 20:37:41 , Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = [1, Z = WARNING] 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 2026-07-21 20:37:41 2026-07-21 20:37:41 [WARNING] [WARNING] 2026-07-21 20:37:41 1. Approximated value used A * amu - Z * m_e instead.[2026-07-21 20:37:41 [WARNINGWARNING] 2026-07-21 20:37:41 [WARNING
# ] nuclearMass: nuclear mass not found in the mass table for A = 2026-07-21 20:37:41 ] [WARNING] 12026-07-21 20:37:41 [WARNING] , Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.nuclearMass: nuclear mass not found in the mass table for
# A = 1, Z = 1nuclearMass: nuclear mass not found in the mass table for . Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = 1nuclearMass: nuclear mass not found in the mass table for . Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = A = nuclearMass: nuclear mass not found in the mass table for A = 11, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# , Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 12026-07-21 20:37:41 , Z = 1. Approximated value used A * amu - Z * m_e instead.[2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 2026-07-21 20:37:41 [WARNING] 2026-07-21 20:37:41 [WARNINGWARNINGnuclearMass: nuclear mass not found in the mass table for ] [] A = WARNING2026-07-21 20:37:41 2026-07-21 20:37:41 [1[WARNING] ] nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for WARNINGA = 1] , Z = 1. Approximated value used A * amu - Z * m_e instead., Z =
# 1nuclearMass: nuclear mass not found in the mass table for A = A = . 1, Z = 1Approximated value used A * amu - Z * m_e instead.
# 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# . Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
#
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 12026-07-21 20:37:41 , Z = 1. Approximated value used A * amu - Z * m_e instead.
# [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 2026-07-21 20:37:41 [WARNING] 1. 2026-07-21 20:37:41 [WARNINGApproximated value used A * amu - Z * m_e instead.] 2026-07-21 20:37:41 [
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 2026-07-21 20:37:41 [WARNING] 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for 2026-07-21 20:37:41 [WARNING] nuclearMass: nuclear mass not found in the mass table for WARNING2026-07-21 20:37:41 ] [1WARNING] nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.nuclearMass: nuclear mass not found in the mass table for A = 1, Z =
# 2026-07-21 20:37:41 1. A = 2026-07-21 20:37:41 [WARNING] [1, Z = A = 1WARNING] nuclearMass: nuclear mass not found in the mass table for , Z = 1. Approximated value used A * amu - Z * m_e instead.
# . Approximated value used A * amu - Z * m_e instead.
# 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
#   Started Tue Jul 21 20:37:40 2026 : [ Finished ] 100%    Needed: 00:00:09  - Finished at Tue Jul 21 20:37:49 2026

# %%
columnnames=['D', 'z', 'ID', 'E', 'X', 'Y', 'Z', 'Px', 'Py', 'Pz','ID0', 'E0', 'X0', 'Y0', 'Z0', 'P0x', 'P0y', 'P0z']
types = [float] * len(columnnames)
import numpy as np
data = np.loadtxt('./output.txt', dtype={'names': columnnames, 'formats': types})

# %%
import matplotlib.pyplot as plt
bins = np.linspace(-0.1,0.1, 10)
plt.hist(data['z'], bins=bins, histtype='step')
plt.xlabel(r'observed redshift $z$')
plt.show()

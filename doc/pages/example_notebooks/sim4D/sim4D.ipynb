# %% [markdown]
# # 4D Simulation
#
# The following is a simple 4D simulation where cosmic rays are emitted by a source at a specified spatial position at a specified time-point. A cosmic ray is detected if it arrives at the observer position within a specified time window.
#
# **Note:** In CRPropa, time is always expressed in terms of redshift $z$, whereas positions are always expressed in terms of comoving coordinates as Cartesian 3-vectors.
#
# ### Simulation setup
# The simulation setup is that of a 3D simulation with a few additions:
# 1. We add a source property for the redshift at emission. This can be either ```SourceRedshift```, ```SourceUniformRedshift``` or ```SourceRedshiftEvolution```.
# 2. The simulation module ```FutureRedshift``` implements adiabatic energy loss and updates the redshift. In contrast to ```Redshift``` it allows particles to be propagated into the future $z < 0$ which enables faster convergence for finite observation windows.
# 3. The observer feature ```ObserverRedshiftWindow``` specifies a time window $z_\mathrm{min} < z < z_\mathrm{max}$ in which particles are detected if they hit the observer. Note that this can also be done after the simulation by cutting on the redshifts at observation. For this we also output the current redshift at observation.
# 4. A minimum redshift is defined via MinimumRedshift which we set to the lower bound of the observer time window.
#
# ### Periodic boundaries
# Due to the additional time dimension, particles are detected much less often. In order to increase the otherwhise horrible simulation efficiency, a ```PeriodicBox``` is defined: Particles that leave this simulation volume, enter again from the opposite side and their source position is moved accordingly.
# As a result the periodic boundaries keep the particles close to the observer and therefore increase the chance of detection. A careful setup is required however:
# 1. Sources should only be defined inside the volume as sources outside are filled up by the periodic conditions.
# 2. The magnetic field at the boundaries should be periodic as well. This is the case for ```initTurbulence``` as long as the simulation volume coincides with (multiples of) the magnetic field grid.
#
# ### Source positions
# In the example below, a single source is defined. For specifying multiple identical discrete sources ```SourceMultiplePositions``` can be used. Multiple non-identical sources can be added to a ```SourceList```. For continous source distributions ```SourceUniformSphere```, ```SourceUniformBox``` and ```SourceUniformCylinder``` can be used. ```SourceDensityGrid``` allows to specify a source distribution via a 3D grid.

# %% [markdown]
# ### Note:
# This simulation may take **several** minutes.

# %%
from crpropa import *


# set up random turbulent field
Brms = 1 * nG
lMin = 60 * kpc
lMax = 800 * kpc
sIndex = 5./3.
turbSpectrum = SimpleTurbulenceSpectrum(Brms, lMin, lMax, sIndex)
gridprops = GridProperties(Vector3d(0), 256, 30 * kpc)
Bfield = SimpleGridTurbulence(turbSpectrum, gridprops, 42)

# simulation setup
sim = ModuleList()
sim.add(PropagationCK(Bfield))
sim.add(FutureRedshift())
#sim.add(FutureRedshift()) # Switch back to FutureRedshift when PR #416 is merged
sim.add(Redshift())
sim.add(PhotoPionProduction(CMB()))
sim.add(PhotoPionProduction(IRB_Kneiske04()))
sim.add(PhotoDisintegration(CMB()))
sim.add(PhotoDisintegration(IRB_Kneiske04()))
sim.add(ElectronPairProduction(CMB()))
sim.add(ElectronPairProduction(IRB_Kneiske04()))
sim.add(NuclearDecay())
sim.add(MinimumEnergy(1 * EeV))
#sim.add(MinimumRedshift(-0.1)) # Switch back to z_min=-0.1 when PR #416 is merged
sim.add(MinimumRedshift(0.))


# periodic boundaries
extent = 256 * 30 * kpc  # size of the magnetic field grid
sim.add(PeriodicBox(Vector3d(-extent), Vector3d(2 * extent)))

# define the observer
obs = Observer()
obs.add(ObserverSurface( Sphere(Vector3d(0.), 0.5 * Mpc)))
obs.add(ObserverRedshiftWindow(-0.1, 0.1))
output = TextOutput('output.txt', Output.Event3D)
output.enable(output.RedshiftColumn)
obs.onDetection(output)
sim.add(obs)

# define the source(s)
source = Source()
source.add(SourcePosition(Vector3d(10, 0, 0) * Mpc))
source.add(SourceIsotropicEmission())
source.add(SourceParticleType(nucleusId(1, 1)))
source.add(SourcePowerLawSpectrum(1 * EeV, 200 * EeV, -1))
source.add(SourceRedshiftEvolution(1.5, 0.001, 3))

# run simulation
sim.setShowProgress(True)
sim.run(source, 10000)
output.close()
# Out:
# crpropa::ModuleList: Number of Threads: 32
# Run ModuleList
#   Started Wed Jul 22 02:56:43 2026 : [>         ]   0%    Finish in: 00:00:00
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 12026-07-22 02:56:43 [WARNING] , Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 12026-07-22 02:56:43 [WARNING] , Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:56:43 [WARNING] A = 1, Z = 1nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# . Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1Approximated value used A * amu - Z * m_e instead.
# . Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:56:43 [WARNING] A = 1, Z = 12026-07-22 02:56:43 [WARNING] . Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:56:43 [A = 1, Z = 1. WARNING] Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 2026-07-22 02:56:43 [WARNING] 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1nuclearMass: nuclear mass not found in the mass table for A = , Z = 1. A = 1Approximated value used A * amu - Z * m_e instead.
# , Z = 1. Approximated value used A * amu - Z * m_e instead.
# 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = ] 1, Z = 1. Approximated value used A * amu - Z * m_e instead.nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1.
# Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 2026-07-22 02:56:43 [WARNING] 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 12026-07-22 02:56:43 [WARNING] . Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] 2026-07-22 02:56:43 nuclearMass: nuclear mass not found in the mass table for A = 1, Z = [WARNING] 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 12026-07-22 02:56:43 [WARNING] . Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1WARNING] . Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 2026-07-22 02:56:43 [WARNING] 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.2026-07-22 02:56:43 [WARNING]
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] 2026-07-22 02:56:43 [nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. WARNING] Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 2026-07-22 02:56:43 [WARNING] 2026-07-22 02:56:43 [[WARNING] WARNINGnuclearMass: nuclear mass not found in the mass table for A = 1] 2026-07-22 02:56:43 [WARNING] , Z = 2026-07-22 02:56:43 [WARNING] 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. 2026-07-22 02:56:43 [WARNING] Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = nuclearMass: nuclear mass not found in the mass table for 1nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for A = 1, Z = A = 1A = 1, Z = . 1Approximated value used A * amu - Z * m_e instead.
# 1. , Z = 1. Approximated value used A * amu - Z * m_e instead.
# . Approximated value used A * amu - Z * m_e instead.
# Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. 2026-07-22 02:56:43 [WARNING] Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. [WARNING] Approximated value used A * amu - Z * m_e instead.2026-07-22 02:56:43 [WARNING] 2026-07-22 02:56:43 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for
# 2026-07-22 02:56:43 2026-07-22 02:56:43 [[WARNING] A = [WARNINGWARNING] ] nuclearMass: nuclear mass not found in the mass table for 12026-07-22 02:56:43 [WARNING] , Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 12026-07-22 02:56:43 [WARNING] . Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 2026-07-22 02:56:43 [WARNING] 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1nuclearMass: nuclear mass not found in the mass table for A = 2026-07-22 02:56:43 [WARNING] 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 2026-07-22 02:56:43 1, Z = 1. Approximated value used A * amu - Z * m_e instead.[WARNING]
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for A = . A = Approximated value used A * amu - Z * m_e instead.1
# , Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. A = 1Approximated value used A * amu - Z * m_e instead.
# 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# , Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.2026-07-22 02:56:43 [WARNING] 2026-07-22 02:56:43
# nuclearMass: nuclear mass not found in the mass table for A = [2026-07-22 02:56:43 WARNING] [WARNING] 1nuclearMass: nuclear mass not found in the mass table for A = 1nuclearMass: nuclear mass not found in the mass table for , Z = , Z = 2026-07-22 02:56:43 [WARNING] 1. Approximated value used A * amu - Z * m_e instead.
# 1. Approximated value used A * amu - Z * m_e instead.
# A = 2026-07-22 02:56:43 12026-07-22 02:56:43 [2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for WARNING] A = 1, Z = 1[WARNING] . Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:56:43 A = 2026-07-22 02:56:43 2026-07-22 02:56:43 [[[WARNING12026-07-22 02:56:43 , Z = ] WARNING] [WARNINGnuclearMass: nuclear mass not found in the mass table for WARNING] ] A = nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for A = 11, Z = nuclearMass: nuclear mass not found in the mass table for 1, Z = nuclearMass: nuclear mass not found in the mass table for . Approximated value used A * amu - Z * m_e instead.1A = . 1A = , Z = 1
# 1A = . 1, Z = Approximated value used A * amu - Z * m_e instead.1.
# Approximated value used A * amu - Z * m_e instead.
# . Approximated value used A * amu - Z * m_e instead.
# 1, Z = 1. Approximated value used A * amu - Z * m_e instead.Approximated value used A * amu - Z * m_e instead.
#
# , Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:56:43 [WARNING] A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = nuclearMass: nuclear mass not found in the mass table for A = 2026-07-22 02:56:43 1, Z = 1[12026-07-22 02:56:43 WARNING[. Approximated value used A * amu - Z * m_e instead.
# . ] 2026-07-22 02:56:43 2026-07-22 02:56:43 WARNING] [[Approximated value used A * amu - Z * m_e instead.WARNINGnuclearMass: nuclear mass not found in the mass table for
# nuclearMass: nuclear mass not found in the mass table for ] A = nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:56:43 WARNINGA = ] 1[WARNING] , Z = 1. Approximated value used A * amu - Z * m_e instead.
# 1, Z = 1. Approximated value used A * amu - Z * m_e instead.nuclearMass: nuclear mass not found in the mass table for
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. 2026-07-22 02:56:43 [WARNING] Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 12026-07-22 02:56:43 [WARNING] . Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1A = nuclearMass: nuclear mass not found in the mass table for A = 1. Approximated value used A * amu - Z * m_e instead.
# 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# , Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] 2026-07-22 02:56:43 2026-07-22 02:56:43 [[nuclearMass: nuclear mass not found in the mass table for A = WARNINGWARNING] 2026-07-22 02:56:43 ] [WARNING] 2026-07-22 02:56:43 2026-07-22 02:56:43 [WARNING1[WARNING] ] , Z = 1nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for A = nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:56:43 2026-07-22 02:56:43 [[WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1WARNING] , Z = 1. Approximated value used A * amu - Z * m_e instead.
# 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# A = 2026-07-22 02:56:43 1, Z = 1[. Approximated value used A * amu - Z * m_e instead.WARNING2026-07-22 02:56:43
# [WARNING] ] nuclearMass: nuclear mass not found in the mass table for A = 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = A = 11nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for A = A = 1. nuclearMass: nuclear mass not found in the mass table for Approximated value used A * amu - Z * m_e instead., Z =
# nuclearMass: nuclear mass not found in the mass table for , Z = 1. Approximated value used A * amu - Z * m_e instead.
# 1, Z = 11. A = Approximated value used A * amu - Z * m_e instead., Z =
# A = 1, Z = 1. 1, Z = 11. 1. . , Z = Approximated value used A * amu - Z * m_e instead.Approximated value used A * amu - Z * m_e instead.Approximated value used A * amu - Z * m_e instead.
#
#
# Approximated value used A * amu - Z * m_e instead.
# 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 2026-07-22 02:56:43 [WARNING] 1, Z = 12026-07-22 02:56:43 2026-07-22 02:56:43 [. Approximated value used A * amu - Z * m_e instead.
# [WARNINGWARNING] ] nuclearMass: nuclear mass not found in the mass table for A = 2026-07-22 02:56:43 1, Z = 1. [2026-07-22 02:56:43 [WARNINGnuclearMass: nuclear mass not found in the mass table for WARNING] A = 1, Z = 1. ] Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:56:43 A = [WARNING] 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1nuclearMass: nuclear mass not found in the mass table for , Z = , Z = A = 1, Z = 12026-07-22 02:56:43 12026-07-22 02:56:43 2026-07-22 02:56:43 2026-07-22 02:56:43 [WARNING2026-07-22 02:56:43 . [WARNING] ] [Approximated value used A * amu - Z * m_e instead.WARNING[WARNING] 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A =
# ] [WARNING] 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = nuclearMass: nuclear mass not found in the mass table for A = nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for A = 1. Approximated value used A * amu - Z * m_e instead.
# 11A = , Z = 1. Approximated value used A * amu - Z * m_e instead.
# 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# . Approximated value used A * amu - Z * m_e instead.
# . Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 12026-07-22 02:56:43 [WARNING] 2026-07-22 02:56:43 2026-07-22 02:56:43 nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:56:43 2026-07-22 02:56:43 A = [WARNING] [1[WARNINGnuclearMass: nuclear mass not found in the mass table for [] WARNINGWARNING, Z = ] 2026-07-22 02:56:43 1] [WARNING] nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:56:43 2026-07-22 02:56:43 [[. nuclearMass: nuclear mass not found in the mass table for A = 1, Z = A = WARNINGWARNING] nuclearMass: nuclear mass not found in the mass table for ] A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for 1. Approximated value used A * amu - Z * m_e instead.
# , Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.Approximated value used A * amu - Z * m_e instead.
#
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 2026-07-22 02:56:43 [WARNING] 2026-07-22 02:56:43 1, Z = [1WARNING] nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 2026-07-22 02:56:43 [WARNING] 1, Z = nuclearMass: nuclear mass not found in the mass table for . A = 2026-07-22 02:56:43 [1WARNING] . Approximated value used A * amu - Z * m_e instead.
# Approximated value used A * amu - Z * m_e instead.2026-07-22 02:56:43 2026-07-22 02:56:43 [WARNING] 2026-07-22 02:56:43 [2026-07-22 02:56:43 [WARNING] WARNING[WARNING] nuclearMass: nuclear mass not found in the mass table for
# A = 2026-07-22 02:56:43 1[, Z = ] nuclearMass: nuclear mass not found in the mass table for WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = 2026-07-22 02:56:43 1. Approximated value used A * amu - Z * m_e instead.
# [1WARNING, Z = 1. Approximated value used A * amu - Z * m_e instead.] nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for A = A = 1A = , Z =
# nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for A = 111, Z = . Approximated value used A * amu - Z * m_e instead.
# 1. 1. Approximated value used A * amu - Z * m_e instead., Z = Approximated value used A * amu - Z * m_e instead.A =
# 1. Approximated value used A * amu - Z * m_e instead.
# 1
# , Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.1
# , Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = ] 2026-07-22 02:56:43 [WARNING] 2026-07-22 02:56:43 [WARNING] 1, Z = 12026-07-22 02:56:43 . 2026-07-22 02:56:43 [WARNING] 2026-07-22 02:56:43 [[Approximated value used A * amu - Z * m_e instead.WARNINGnuclearMass: nuclear mass not found in the mass table for A = WARNING1] 2026-07-22 02:56:43 2026-07-22 02:56:43
# [, Z = ] nuclearMass: nuclear mass not found in the mass table for [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 2026-07-22 02:56:43 WARNING] [WARNING] A = 12026-07-22 02:56:43 2026-07-22 02:56:43 [WARNING] [WARNING] , Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 11, Z = 1nuclearMass: nuclear mass not found in the mass table for , Z = A = 1. nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:56:43 [WARNINGApproximated value used A * amu - Z * m_e instead.]
# 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# . Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for 1nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = 1. . Approximated value used A * amu - Z * m_e instead.nuclearMass: nuclear mass not found in the mass table for
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 2026-07-22 02:56:43 1, Z = 1[WARNING2026-07-22 02:56:43 ] . Approximated value used A * amu - Z * m_e instead.[WARNING]
# nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:56:43 A = 2026-07-22 02:56:43 [WARNING1[WARNING] , Z = ] 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:56:43 [WARNING] [WARNING] A = 1, Z = 1. nuclearMass: nuclear mass not found in the mass table for Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 0. A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. 2026-07-22 02:56:43 [Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 2026-07-22 02:56:43 WARNING[[nuclearMass: nuclear mass not found in the mass table for WARNING2026-07-22 02:56:43 ] WARNING] [A = 2026-07-22 02:56:43 WARNING] [WARNING2026-07-22 02:56:43 ] [WARNING] ] 1, Z = 1. Approximated value used A * amu - Z * m_e instead.nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:56:43 [WARNING] A =
# 1, Z = 2026-07-22 02:56:43 2026-07-22 02:56:43 1. Approximated value used A * amu - Z * m_e instead.[
# Approximated value used A * amu - Z * m_e instead.WARNING
# nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:56:43 [WARNINGA = ] 1[WARNING] , Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for ] 2026-07-22 02:56:43 [nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:56:43 [WARNING] WARNING] A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.nuclearMass: nuclear mass not found in the mass table for A = 1
# , Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. nuclearMass: nuclear mass not found in the mass table for Approximated value used A * amu - Z * m_e instead.A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
#
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
#
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:56:43 [WARNING] 2026-07-22 02:56:43 [WARNING] A = 1, Z = 1. nuclearMass: nuclear mass not found in the mass table for A = 1, Z = nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING2026-07-22 02:56:43 ] 2026-07-22 02:56:43 [1. Approximated value used A * amu - Z * m_e instead.2026-07-22 02:56:43 WARNING[WARNING] 2026-07-22 02:56:43
# Approximated value used A * amu - Z * m_e instead.[
# [2026-07-22 02:56:43 [2026-07-22 02:56:43 WARNING[nuclearMass: nuclear mass not found in the mass table for ] WARNINGWARNING] WARNING] 2026-07-22 02:56:43 ] [WARNING] ] A = 2026-07-22 02:56:43 [WARNING] 12026-07-22 02:56:43 [WARNING] , Z = 1. nuclearMass: nuclear mass not found in the mass table for A = Approximated value used A * amu - Z * m_e instead.nuclearMass: nuclear mass not found in the mass table for
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. 2026-07-22 02:56:43 2026-07-22 02:56:43 2026-07-22 02:56:43 [WARNING] [WARNING] 2026-07-22 02:56:43 [WARNING] [WARNING] Approximated value used A * amu - Z * m_e instead.nuclearMass: nuclear mass not found in the mass table for
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.nuclearMass: nuclear mass not found in the mass table for
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for A = 1
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.1
# . Approximated value used A * amu - Z * m_e instead.
# , Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# . Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] 2026-07-22 02:56:43 [WARNING] 2026-07-22 02:56:43 [2026-07-22 02:56:43 nuclearMass: nuclear mass not found in the mass table for [2026-07-22 02:56:43 A = [WARNING12026-07-22 02:56:43 WARNING] ] , Z = WARNING1[WARNING] nuclearMass: nuclear mass not found in the mass table for ] nuclearMass: nuclear mass not found in the mass table for A = A = 12026-07-22 02:56:43 [2026-07-22 02:56:43 WARNING1[WARNING] , Z = 1. Approximated value used A * amu - Z * m_e instead.
# . Approximated value used A * amu - Z * m_e instead.
# , Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:56:43 A = [1WARNING2026-07-22 02:56:43 ] [WARNING] , Z = ] nuclearMass: nuclear mass not found in the mass table for A = 12026-07-22 02:56:43 [WARNINGnuclearMass: nuclear mass not found in the mass table for ] A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.1. Approximated value used A * amu - Z * m_e instead.2026-07-22 02:56:43 [WARNING]
#
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = , Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = nuclearMass: nuclear mass not found in the mass table for A = 12026-07-22 02:56:43 2026-07-22 02:56:43 [WARNING] 2026-07-22 02:56:43 [WARNING] [, Z = WARNING] 1. Approximated value used A * amu - Z * m_e instead.2026-07-22 02:56:43 [WARNING]
# Approximated value used A * amu - Z * m_e instead.
# 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = 1. 1nuclearMass: nuclear mass not found in the mass table for , Z = nuclearMass: nuclear mass not found in the mass table for 1. Approximated value used A * amu - Z * m_e instead.
# Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.2026-07-22 02:56:43 [2026-07-22 02:56:43
# [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# WARNING2026-07-22 02:56:43 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 12026-07-22 02:56:43 [[. Approximated value used A * amu - Z * m_e instead.WARNING] WARNINGnuclearMass: nuclear mass not found in the mass table for ]
# ] 2026-07-22 02:56:43 2026-07-22 02:56:43 [WARNINGA = ] 1, Z = 1. [WARNING] Approximated value used A * amu - Z * m_e instead.2026-07-22 02:56:43 [
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = nuclearMass: nuclear mass not found in the mass table for A = 2026-07-22 02:56:43 WARNING] 2026-07-22 02:56:43 [[WARNING] WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. 1, Z = 2026-07-22 02:56:43 [WARNING2026-07-22 02:56:43 [] 12026-07-22 02:56:43 [. WARNING] Approximated value used A * amu - Z * m_e instead.
# WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:56:43 [WARNING] A = 1, Z = 12026-07-22 02:56:43 [2026-07-22 02:56:43 2026-07-22 02:56:43 2026-07-22 02:56:43 [WARNING] [[WARNINGWARNING. ] Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for WARNING] ] A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1Approximated value used A * amu - Z * m_e instead..
# nuclearMass: nuclear mass not found in the mass table for A = 1nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for A = 1nuclearMass: nuclear mass not found in the mass table for A = 1, Z = nuclearMass: nuclear mass not found in the mass table for 1A = 1, Z = 1, Z = . Approximated value used A * amu - Z * m_e instead., Z = 1. Approximated value used A * amu - Z * m_e instead.
#
# . Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 1. Approximated value used A * amu - Z * m_e instead.
# 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 12026-07-22 02:56:43 [WARNING] . Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [2026-07-22 02:56:43 nuclearMass: nuclear mass not found in the mass table for [WARNINGA = ] WARNING1] , Z = 1. 2026-07-22 02:56:43 Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:56:43 A = [WARNING[2026-07-22 02:56:43 [] WARNINGWARNING1] ] , Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNINGnuclearMass: nuclear mass not found in the mass table for ] 2026-07-22 02:56:43 A = 1[, Z = 1. Approximated value used A * amu - Z * m_e instead.WARNING]
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:56:43 [WARNING] A = 2026-07-22 02:56:43 12026-07-22 02:56:43 [, Z = [nuclearMass: nuclear mass not found in the mass table for WARNING] 2026-07-22 02:56:43 [WARNING] A = 2026-07-22 02:56:43 WARNING] [WARNING] 1, Z = 2026-07-22 02:56:43 [WARNING] 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:56:43 [WARNING] A = 1, Z = nuclearMass: nuclear mass not found in the mass table for A = 1Approximated value used A * amu - Z * m_e instead., Z =
# 2026-07-22 02:56:43 [2026-07-22 02:56:43 WARNING] 2026-07-22 02:56:43 [1[WARNING] . Approximated value used A * amu - Z * m_e instead.
# WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = nuclearMass: nuclear mass not found in the mass table for 1. Approximated value used A * amu - Z * m_e instead.
# 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.nuclearMass: nuclear mass not found in the mass table for
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# . Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:56:43 [WARNING] A = 1, Z = 1. 2026-07-22 02:56:43 [Approximated value used A * amu - Z * m_e instead.2026-07-22 02:56:43 WARNING[WARNING] nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:56:43 [WARNING] 2026-07-22 02:56:43 A = 1[WARNING] ] 2026-07-22 02:56:43
# [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 12026-07-22 02:56:43 [WARNING] , Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] , Z = 2026-07-22 02:56:43 [WARNING] 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:56:43 [A = WARNING] 1[2026-07-22 02:56:43 [WARNING] , Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.2026-07-22 02:56:43 [WARNING]
# nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:56:43 A = 2026-07-22 02:56:43 1[2026-07-22 02:56:43 [2026-07-22 02:56:43 [WARNINGWARNING, Z = [WARNING] WARNING1] ] ] . Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for WARNING] A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1nuclearMass: nuclear mass not found in the mass table for , Z = 1nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1nuclearMass: nuclear mass not found in the mass table for , Z = nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.. Approximated value used A * amu - Z * m_e instead.nuclearMass: nuclear mass not found in the mass table for
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
#
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. A = Approximated value used A * amu - Z * m_e instead.1. , Z =
# 1. Approximated value used A * amu - Z * m_e instead.
# 1. Approximated value used A * amu - Z * m_e instead.
# Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 12026-07-22 02:56:43 [WARNING2026-07-22 02:56:43 2026-07-22 02:56:43 [WARNING] , Z = 1. 2026-07-22 02:56:43 [WARNING2026-07-22 02:56:43 [[2026-07-22 02:56:43 ] WARNINGApproximated value used A * amu - Z * m_e instead.] 2026-07-22 02:56:43 [] nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:56:43
# WARNING] [[WARNINGWARNINGWARNING2026-07-22 02:56:43 ] [A = ] 2026-07-22 02:56:43 WARNING] [2026-07-22 02:56:43 1[2026-07-22 02:56:43 , Z = [WARNING1WARNING. WARNING] ] ] ] nuclearMass: nuclear mass not found in the mass table for Approximated value used A * amu - Z * m_e instead.nuclearMass: nuclear mass not found in the mass table for
# A = 1nuclearMass: nuclear mass not found in the mass table for , Z = A = 11nuclearMass: nuclear mass not found in the mass table for , Z = A = 1nuclearMass: nuclear mass not found in the mass table for . A = . nuclearMass: nuclear mass not found in the mass table for A = 12026-07-22 02:56:43 [WARNING] , Z = 2026-07-22 02:56:43 [WARNING] 12026-07-22 02:56:43 [WARNING] . Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 12026-07-22 02:56:43 2026-07-22 02:56:43 [, Z = [2026-07-22 02:56:43 [WARNING] WARNINGWARNING] 1nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for ] A = 11, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.1, Z = 1
# . Approximated value used A * amu - Z * m_e instead.
# . Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for A = nuclearMass: nuclear mass not found in the mass table for 1, Z = 1nuclearMass: nuclear mass not found in the mass table for . Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for Approximated value used A * amu - Z * m_e instead.
# Approximated value used A * amu - Z * m_e instead.
# , Z = 1. Approximated value used A * amu - Z * m_e instead.
# A = A = A = 11A = , Z = A = A = 11, Z = 1. Approximated value used A * amu - Z * m_e instead., Z = , Z =
# A = Approximated value used A * amu - Z * m_e instead.
# 1. Approximated value used A * amu - Z * m_e instead.1
# , Z = 1. Approximated value used A * amu - Z * m_e instead.
# 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 1. Approximated value used A * amu - Z * m_e instead.
# 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 12026-07-22 02:56:43 [WARNING] 2026-07-22 02:56:43 [WARNING] , Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.2026-07-22 02:56:43 [WARNING]
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:56:43 [WARNING] 2026-07-22 02:56:43 [WARNING2026-07-22 02:56:43 A = ] 2026-07-22 02:56:43 [WARNING] 1[, Z = nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:56:43 [WARNING] WARNING] A = 2026-07-22 02:56:43 1[WARNING] 2026-07-22 02:56:43 [WARNING] , Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:56:43 A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.2026-07-22 02:56:43 [WARNING] [nuclearMass: nuclear mass not found in the mass table for
# 2026-07-22 02:56:43 A = 1[WARNINGWARNING] ] , Z = 2026-07-22 02:56:43 2026-07-22 02:56:43 [[1. Approximated value used A * amu - Z * m_e instead.WARNING
# WARNING] 2026-07-22 02:56:43 [] nuclearMass: nuclear mass not found in the mass table for A = 2026-07-22 02:56:43 1, Z = 1. WARNING2026-07-22 02:56:43 [2026-07-22 02:56:43 [] Approximated value used A * amu - Z * m_e instead.2026-07-22 02:56:43 WARNING2026-07-22 02:56:43 [1[WARNING[2026-07-22 02:56:43 nuclearMass: nuclear mass not found in the mass table for
# WARNING[] WARNINGWARNING] ] ] WARNING] A = nuclearMass: nuclear mass not found in the mass table for ] nuclearMass: nuclear mass not found in the mass table for A = nuclearMass: nuclear mass not found in the mass table for A = 1, Z = nuclearMass: nuclear mass not found in the mass table for 1A = nuclearMass: nuclear mass not found in the mass table for A = nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = nuclearMass: nuclear mass not found in the mass table for A = 1. 1. , Z = nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for 1, Z = A = 1. Approximated value used A * amu - Z * m_e instead.
# 1, Z = nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# . nuclearMass: nuclear mass not found in the mass table for Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = Approximated value used A * amu - Z * m_e instead.A =
# 1, Z = 1A = 1111. Approximated value used A * amu - Z * m_e instead.A =
# 11. Approximated value used A * amu - Z * m_e instead.
# 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# , Z = 1. Approximated value used A * amu - Z * m_e instead.
# , Z = 1. Approximated value used A * amu - Z * m_e instead.
# Approximated value used A * amu - Z * m_e instead.
# . Approximated value used A * amu - Z * m_e instead.
# 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# . Approximated value used A * amu - Z * m_e instead.
# , Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING2026-07-22 02:56:43 2026-07-22 02:56:43 [WARNING] ] [WARNINGnuclearMass: nuclear mass not found in the mass table for A = 12026-07-22 02:56:43 , Z = 1. Approximated value used A * amu - Z * m_e instead.[2026-07-22 02:56:43 WARNING[
# ...
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. nuclearMass: nuclear mass not found in the mass table for Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = nuclearMass: nuclear mass not found in the mass table for 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = A = nuclearMass: nuclear mass not found in the mass table for 1A = . A = 1, Z = 1. nuclearMass: nuclear mass not found in the mass table for 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# Approximated value used A * amu - Z * m_e instead.Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 2026-07-22 02:56:43 [WARNING] 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# [nuclearMass: nuclear mass not found in the mass table for A = 2026-07-22 02:56:43 2026-07-22 02:56:43 [WARNING[12026-07-22 02:56:43 [, Z = ] 1WARNING] 2026-07-22 02:56:43 . Approximated value used A * amu - Z * m_e instead.[
# nuclearMass: nuclear mass not found in the mass table for A = WARNINGWARNING] ] WARNING] nuclearMass: nuclear mass not found in the mass table for A = 2026-07-22 02:56:43 [WARNING] 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 12026-07-22 02:56:43 [WARNING] . 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.1
# , Z = 1. Approximated value used A * amu - Z * m_e instead.nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for A = 1, Z =
# 1. Approximated value used A * amu - Z * m_e instead.
# 1, Z = 1. 2026-07-22 02:56:43 [WARNING] Approximated value used A * amu - Z * m_e instead.
# Approximated value used A * amu - Z * m_e instead.2026-07-22 02:56:43 [
# WARNING] nuclearMass: nuclear mass not found in the mass table for A = 12026-07-22 02:56:43 [WARNING] , Z = 2026-07-22 02:56:43 [WARNING] 1. Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.2026-07-22 02:56:43 A = 2026-07-22 02:56:43 [
# 2026-07-22 02:56:43 [WARNING] [WARNINGnuclearMass: nuclear mass not found in the mass table for A = 2026-07-22 02:56:43 WARNING[WARNING] 2026-07-22 02:56:43 [WARNING] 1] 2026-07-22 02:56:43 [WARNING] ] nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for A = 11, Z = 1nuclearMass: nuclear mass not found in the mass table for A = A = 11, Z = 1. nuclearMass: nuclear mass not found in the mass table for Approximated value used A * amu - Z * m_e instead.
# A = , Z = 1. Approximated value used A * amu - Z * m_e instead.
# , Z = nuclearMass: nuclear mass not found in the mass table for 1. Approximated value used A * amu - Z * m_e instead.
# . Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. A = 1, Z = 1, Z = . Approximated value used A * amu - Z * m_e instead.1, Z = 1.
# Approximated value used A * amu - Z * m_e instead.
# Approximated value used A * amu - Z * m_e instead.
# 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] 2026-07-22 02:56:43 [WARNING] 2026-07-22 02:56:43 [nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:56:43 [WARNING] WARNING] A = 1, Z = 1nuclearMass: nuclear mass not found in the mass table for . Approximated value used A * amu - Z * m_e instead.2026-07-22 02:56:43 [WARNING] A =
# nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:56:43 [A = WARNING1] , Z = 1. 2026-07-22 02:56:43 Approximated value used A * amu - Z * m_e instead.[WARNING
# nuclearMass: nuclear mass not found in the mass table for ] A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:56:43 [A = WARNING2026-07-22 02:56:43 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# [2026-07-22 02:56:43 [WARNING] 1] , Z = WARNING2026-07-22 02:56:43 [WARNING] 1] . Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNINGnuclearMass: nuclear mass not found in the mass table for ] A = 1, Z = 2026-07-22 02:56:43 1. [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.nuclearMass: nuclear mass not found in the mass table for
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.2026-07-22 02:56:43 [WARNING]
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for ] nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:56:43 A = [WARNING] A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.2026-07-22 02:56:43 [WARNING]
# 2026-07-22 02:56:43 [WARNING1, Z = 1. Approximated value used A * amu - Z * m_e instead.2026-07-22 02:56:43 [
# ] nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for WARNING2026-07-22 02:56:43 [] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = WARNING] 1. Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = 1. nuclearMass: nuclear mass not found in the mass table for A = A = 1, Z = 1Approximated value used A * amu - Z * m_e instead.1
# , Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# . Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 12026-07-22 02:56:43 [WARNING2026-07-22 02:56:43 . Approximated value used A * amu - Z * m_e instead.
# [WARNING] 2026-07-22 02:56:43 2026-07-22 02:56:43 ] [WARNING] [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1nuclearMass: nuclear mass not found in the mass table for A = 2026-07-22 02:56:43 [WARNING] 12026-07-22 02:56:43 , Z = 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for 1. A = [WARNING] 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = Approximated value used A * amu - Z * m_e instead.
# . 2026-07-22 02:56:43 [WARNING] Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 11. nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for A = 1, Z = Approximated value used A * amu - Z * m_e instead..
# Approximated value used A * amu - Z * m_e instead.2026-07-22 02:56:43 A = 1, Z = [WARNING2026-07-22 02:56:43 ]
# 2026-07-22 02:56:43 [WARNING] [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.2026-07-22 02:56:43 [WARNING] 2026-07-22 02:56:43 [WARNING]
# 2026-07-22 02:56:43 nuclearMass: nuclear mass not found in the mass table for [A = 2026-07-22 02:56:43 [WARNING] 1WARNING] nuclearMass: nuclear mass not found in the mass table for , Z = nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:56:43 nuclearMass: nuclear mass not found in the mass table for A = 2026-07-22 02:56:43 A = [1[1WARNING] 2026-07-22 02:56:43 WARNING] [WARNING2026-07-22 02:56:43 [nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:56:43 [WARNING] ] WARNING] nuclearMass: nuclear mass not found in the mass table for A = A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = A = 11nuclearMass: nuclear mass not found in the mass table for , Z = 1. Approximated value used A * amu - Z * m_e instead.
# 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# , Z = 1. Approximated value used A * amu - Z * m_e instead.
# . Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# , Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 12026-07-22 02:56:43 [WARNING] , Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 12026-07-22 02:56:43 2026-07-22 02:56:43 [WARNING[WARNING] ] . Approximated value used A * amu - Z * m_e instead.2026-07-22 02:56:43 [WARNING]
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for A = 1, Z = A = 1nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# . Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 12026-07-22 02:56:43 [WARNING] . Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:56:43 [A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:56:43 [WARNING] WARNINGnuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1] 2026-07-22 02:56:43 [WARNING] . Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:56:43 [WARNING] 2026-07-22 02:56:43 [WARNING] A = 2026-07-22 02:56:43 [WARNING1, Z = ] nuclearMass: nuclear mass not found in the mass table for A = nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:56:43 2026-07-22 02:56:43 [WARNING] A = 2026-07-22 02:56:43 [WARNING[WARNING] 1, Z = ] 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 0. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.nuclearMass: nuclear mass not found in the mass table for
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 11, Z = 1nuclearMass: nuclear mass not found in the mass table for A = 11. Approximated value used A * amu - Z * m_e instead.
# . Approximated value used A * amu - Z * m_e instead.
# . Approximated value used A * amu - Z * m_e instead.
# , Z = 1. Approximated value used A * amu - Z * m_e instead.
#   Started Wed Jul 22 02:56:43 2026 : [ Finished ] 100%    Needed: 00:00:10  - Finished at Wed Jul 22 02:56:53 2026

# %%
columnnames=['D', 'z', 'ID', 'E', 'X', 'Y', 'Z', 'Px', 'Py', 'Pz','ID0', 'E0', 'X0', 'Y0', 'Z0', 'P0x', 'P0y', 'P0z']
types = [float] * len(columnnames)
import numpy as np
data = np.loadtxt('./output.txt', dtype={'names': columnnames, 'formats': types})

# %%
import matplotlib.pyplot as plt
bins = np.linspace(-0.1,0.1, 10)
plt.hist(data['z'], bins=bins, histtype='step')
plt.xlabel(r'observed redshift $z$')
plt.show()

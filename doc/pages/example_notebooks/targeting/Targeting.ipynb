# %% [markdown]
# ## The targeting algorithm of CRPropa
#
# Here, we will introduce you to the targeting algorithm in CRPropa, which emits particles from their sources using a von-Mises-Fisher distribution instead of an isotropic distribution. After emission from their sources, the particles get a weight assigned to them so that the resulting distribution at the observer can be reweighted to resemble an isotropically emitted distribution from the sources. This can lead to significantly larger number of hits compared with starting with an isotropic emission.

# %% [markdown]
# ### A simple example on how to use the targeting algorithm of CRPropa

# %%
import numpy as np
from crpropa import *

# Create a random magnetic-field setup
randomSeed = 42
turbSpectrum = SimpleTurbulenceSpectrum(0.2*nG, 200*kpc, 2*Mpc, 5./3.)
gridprops = GridProperties(Vector3d(0), 256, 100*kpc)
BField = SimpleGridTurbulence(turbSpectrum, gridprops, randomSeed)

# Cosmic-ray propagation in magnetic fields without interactions
sim = ModuleList()
sim.add(PropagationCK(BField))
sim.add(MaximumTrajectoryLength(25 * Mpc))

# Define an observer
sourcePosition = Vector3d(2., 2., 2.) * Mpc
obsPosition = Vector3d(2., 10., 2.) * Mpc
obsRadius = 2. * Mpc

obs = Observer()
obs.add(ObserverSurface( Sphere(obsPosition, obsRadius)))
obs.setDeactivateOnDetection(True)
FilenameObserver = 'TargetedEmission.txt'
output = TextOutput(FilenameObserver)
output.disable(output.CandidateTagColumn)
obs.onDetection(output)
sim.add(obs)
    
# Define the vMF source
source = Source()
source.add(SourcePosition(sourcePosition))
source.add(SourceParticleType(nucleusId(1,1)))
source.add(SourceEnergy(10. * EeV))

# Here we need to add the vMF parameters
mu = np.array([0.,1.,0.]) # The average direction emission, pointing from the source to the observer
muvec = Vector3d(float(mu[0]), float(mu[1]), float(mu[2]))
kappa = 100. # The concentration parameter, set to a relatively large value
nparticles = 100000

source.add(SourceDirectedEmission(muvec,kappa))

#now we run the simulation
sim.setShowProgress(True)
sim.run(source, nparticles)
output.close()
# Out:
# crpropa::ModuleList: Number of Threads: 32
# Run ModuleList
#   Started Wed Jul 22 02:57:02 2026 : [======>   ]  63%    Finish in: 00:00:00
# 2026-07-22 02:57:02 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:57:02 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:57:02 2026-07-22 02:57:02 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1[, Z = 1. Approximated value used A * amu - Z * m_e instead.
# WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:57:02 [2026-07-22 02:57:02 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = WARNING] 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:57:02 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 12026-07-22 02:57:02 [WARNING] . 2026-07-22 02:57:02 [WARNING] Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:57:02 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. 2026-07-22 02:57:02 [WARNING] Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 2026-07-22 02:57:02 [WARNING] 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:57:02 [WARNINGA = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# ] nuclearMass: nuclear mass not found in the mass table for A = 2026-07-22 02:57:02 [WARNING] 12026-07-22 02:57:02 [WARNING] , Z = nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 1. Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:57:02 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:57:02 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:57:02 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:57:02 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:57:02 2026-07-22 02:57:02 [2026-07-22 02:57:02 [WARNING] nuclearMass: nuclear mass not found in the mass table for WARNING[2026-07-22 02:57:02 ] [WARNING] WARNING] nuclearMass: nuclear mass not found in the mass table for A = 12026-07-22 02:57:02 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# , Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. nuclearMass: nuclear mass not found in the mass table for Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:57:02 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 2026-07-22 02:57:02 2026-07-22 02:57:02 2026-07-22 02:57:02 [WARNING[] WARNING2026-07-22 02:57:02 1] 2026-07-22 02:57:02 [, Z = [WARNING[WARNING] WARNING] 1. Approximated value used A * amu - Z * m_e instead.] nuclearMass: nuclear mass not found in the mass table for
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.nuclearMass: nuclear mass not found in the mass table for
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:57:02 [A = 1, Z = 1WARNING] . Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:57:02 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:57:02 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z =
uclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for A = 1nuclearMass: nuclear mass not found in the mass table for A = nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for A = A = nuclearMass: nuclear mass not found in the mass table for Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1nuclearMass: nuclear mass not found in the mass table for A = 1nuclearMass: nuclear mass not found in the mass table for , Z = 1, Z = 1A = nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# . Approximated value used A * amu - Z * m_e instead.
# A = 1A = 1, Z = , Z = 1. 1, Z = 1. Approximated value used A * amu - Z * m_e instead.1A = nuclearMass: nuclear mass not found in the mass table for
# A = A = 1, Z = Approximated value used A * amu - Z * m_e instead..
# 1nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# . Approximated value used A * amu - Z * m_e instead.
# 1. Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = Approximated value used A * amu - Z * m_e instead.
# . Approximated value used A * amu - Z * m_e instead.
# 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 1, Z = 1. Approximated value used A * amu - Z * m_e instead.. Approximated value used A * amu - Z * m_e instead.
# 1, Z =
# 1. Approximated value used A * amu - Z * m_e instead.
# 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:57:02 [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 12026-07-22 02:57:02 [WARNING] . 2026-07-22 02:57:02 2026-07-22 02:57:02 [[2026-07-22 02:57:02 [WARNINGWARNING] Approximated value used A * amu - Z * m_e instead.2026-07-22 02:57:02 [WARNING] 2026-07-22 02:57:02 [WARNING]
# nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:57:02 WARNING[WARNING] 2026-07-22 02:57:02 ] [] WARNING] 2026-07-22 02:57:02 [A = WARNING] 1nuclearMass: nuclear mass not found in the mass table for A = 2026-07-22 02:57:02 [WARNING2026-07-22 02:57:02 [WARNING] ] 2026-07-22 02:57:02 [WARNING] nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:57:02 [WARNING] A = 1, Z = 2026-07-22 02:57:02 [WARNING] 12026-07-22 02:57:02 [WARNINGnuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:57:02 [2026-07-22 02:57:02 A = [] WARNING2026-07-22 02:57:02 WARNING] [2026-07-22 02:57:02 ] 1WARNING, Z = 1[2026-07-22 02:57:02 [WARNING] nuclearMass: nuclear mass not found in the mass table for ] WARNING2026-07-22 02:57:02 2026-07-22 02:57:02 ] A = [WARNING] nuclearMass: nuclear mass not found in the mass table for A = 1[, Z = 1nuclearMass: nuclear mass not found in the mass table for WARNINGA = nuclearMass: nuclear mass not found in the mass table for ] nuclearMass: nuclear mass not found in the mass table for A = 1, Z = , Z = 1. nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 11. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for A = 11, Z = 1. nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.nuclearMass: nuclear mass not found in the mass table for
# A = 1, Z = 1nuclearMass: nuclear mass not found in the mass table for A = nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for 1Approximated value used A * amu - Z * m_e instead.
# . Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead., Z =
# 1. Approximated value used A * amu - Z * m_e instead.
# Approximated value used A * amu - Z * m_e instead.
# 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# . Approximated value used A * amu - Z * m_e instead.
# . Approximated value used A * amu - Z * m_e instead.
# 1, Z = 1A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# . Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = nuclearMass: nuclear mass not found in the mass table for 1nuclearMass: nuclear mass not found in the mass table for . Approximated value used A * amu - Z * m_e instead.
# . Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for , Z = 1. Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# . Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# ...
# 2026-07-22 02:57:02 2026-07-22 02:57:02 [WARNING] 2026-07-22 02:57:02 [WARNING] [nuclearMass: nuclear mass not found in the mass table for A = WARNING] 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for A = nuclearMass: nuclear mass not found in the mass table for 1nuclearMass: nuclear mass not found in the mass table for A = nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for A = nuclearMass: nuclear mass not found in the mass table for 1, Z = A = nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for A = 1, Z = nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for A = A = 111A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.nuclearMass: nuclear mass not found in the mass table for 1
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1nuclearMass: nuclear mass not found in the mass table for 1A = nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# . Approximated value used A * amu - Z * m_e instead.
# , Z = 1. Approximated value used A * amu - Z * m_e instead.
# , Z = 1. Approximated value used A * amu - Z * m_e instead.
# 1. Approximated value used A * amu - Z * m_e instead.
# , Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# . Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# . Approximated value used A * amu - Z * m_e instead.
# 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# , Z = 1. Approximated value used A * amu - Z * m_e instead.
# Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:57:02 [WARNING] nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:57:02 [WARNING] 2026-07-22 02:57:02 [2026-07-22 02:57:02 [WARNING] 2026-07-22 02:57:02 [WARNING] A = WARNING] 2026-07-22 02:57:02 [WARNING] 1, Z = 2026-07-22 02:57:02 2026-07-22 02:57:02 [WARNING] 2026-07-22 02:57:02 [WARNING] [WARNING] 2026-07-22 02:57:02 2026-07-22 02:57:02 [WARNING] 12026-07-22 02:57:02 [[2026-07-22 02:57:02 2026-07-22 02:57:02 [WARNING[WARNINGWARNING] . 2026-07-22 02:57:02 ] [WARNING] ] WARNINGnuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for A = nuclearMass: nuclear mass not found in the mass table for ] 2026-07-22 02:57:02 [WARNING] 2026-07-22 02:57:02 2026-07-22 02:57:02 A = nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:57:02 nuclearMass: nuclear mass not found in the mass table for [2026-07-22 02:57:02 [WARNINGWARNING] [nuclearMass: nuclear mass not found in the mass table for ] WARNINGA = [2026-07-22 02:57:02 [WARNING] 2026-07-22 02:57:02 ] WARNING12026-07-22 02:57:02 2026-07-22 02:57:02 ] [[WARNING2026-07-22 02:57:02 [WARNING] [WARNINGWARNING] nuclearMass: nuclear mass not found in the mass table for A = ] nuclearMass: nuclear mass not found in the mass table for 1A = ] 1, Z = 1. Approximated value used A * amu - Z * m_e instead.nuclearMass: nuclear mass not found in the mass table for
# A = 1, Z = 1. A = 1, Z = 1. nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1nuclearMass: nuclear mass not found in the mass table for . Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. nuclearMass: nuclear mass not found in the mass table for Approximated value used A * amu - Z * m_e instead.nuclearMass: nuclear mass not found in the mass table for
# A = Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.nuclearMass: nuclear mass not found in the mass table for
# A = 1, Z = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.A =
# 1, Z = 1. Approximated value used A * amu - Z * m_e instead.nuclearMass: nuclear mass not found in the mass table for A =
# 1, Z = nuclearMass: nuclear mass not found in the mass table for 1. 1nuclearMass: nuclear mass not found in the mass table for , Z = A = 11A = nuclearMass: nuclear mass not found in the mass table for A = , Z = A = nuclearMass: nuclear mass not found in the mass table for Approximated value used A * amu - Z * m_e instead., Z =
# 1. Approximated value used A * amu - Z * m_e instead.
# 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 1. Approximated value used A * amu - Z * m_e instead.
# 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = 1. A = Approximated value used A * amu - Z * m_e instead.1, Z =
# 1. Approximated value used A * amu - Z * m_e instead.
# Approximated value used A * amu - Z * m_e instead.
# 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# , Z = 1. Approximated value used A * amu - Z * m_e instead.
# 1. Approximated value used A * amu - Z * m_e instead.
# . Approximated value used A * amu - Z * m_e instead.
# 2026-07-22 02:57:02 [WARNING] nuclearMass: nuclear mass not found in the mass table for 2026-07-22 02:57:02 
1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. nuclearMass: nuclear mass not found in the mass table for A = 1nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for A = nuclearMass: nuclear mass not found in the mass table for A = nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for A = nuclearMass: nuclear mass not found in the mass table for 1, Z = 1nuclearMass: nuclear mass not found in the mass table for . A = 1, Z = 1nuclearMass: nuclear mass not found in the mass table for 1A = . 1nuclearMass: nuclear mass not found in the mass table for nuclearMass: nuclear mass not found in the mass table for , Z = 1, Z = 1. A = nuclearMass: nuclear mass not found in the mass table for A = A = A = 1A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# . Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = 1nuclearMass: nuclear mass not found in the mass table for . , Z = Approximated value used A * amu - Z * m_e instead.
# Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 1. Approximated value used A * amu - Z * m_e instead.1
# , Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = nuclearMass: nuclear mass not found in the mass table for 1A = . 1A = nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# nuclearMass: nuclear mass not found in the mass table for A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# A = nuclearMass: nuclear mass not found in the mass table for A = 1A = Approximated value used A * amu - Z * m_e instead.1
# A = 1, Z = 11nuclearMass: nuclear mass not found in the mass table for , Z = 1, Z = 1Approximated value used A * amu - Z * m_e instead.
# , Z = 1, Z = , Z = 1Approximated value used A * amu - Z * m_e instead..
# Approximated value used A * amu - Z * m_e instead.
# A = 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# . Approximated value used A * amu - Z * m_e instead.
# 1. Approximated value used A * amu - Z * m_e instead.
# 1. Approximated value used A * amu - Z * m_e instead.
# , Z = 1. Approximated value used A * amu - Z * m_e instead.
# 1. Approximated value used A * amu - Z * m_e instead.
# 1. Approximated value used A * amu - Z * m_e instead.
# 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# 1, Z = 1. Approximated value used A * amu - Z * m_e instead.
# . Approximated value used A * amu - Z * m_e instead.
# , Z = 1. Approximated value used A * amu - Z * m_e instead.
# Approximated value used A * amu - Z * m_e instead.
#   Started Wed Jul 22 02:57:02 2026 : [ Finished ] 100%    Needed: 00:00:00  - Finished at Wed Jul 22 02:57:02 2026

# %% [markdown]
# ### Plotting of the results

# %% [markdown]
# ### A learning algorithm to obtain optimal values for mu and kappa

# %%
import numpy as np
from crpropa import *
import os.path
import time
import traceback

def run_batch(mu,kappa,nbatch,epoch):
    # Setup new batch simulation
    def run_sim(mu,kappa,nbatch,epoch):
        sim = ModuleList()
        sim.add( SimplePropagation(5.*parsec, 0.5*Mpc) )
        sim.add(MaximumTrajectoryLength(2000.*Mpc))

        sourcePosition = Vector3d(100., 0., 0.) * Mpc
        obsPosition = Vector3d(0., 0., 0.) * Mpc

        obs = Observer()
        obs.add(ObserverSurface( Sphere(sourcePosition, 50. * parsec)))
        obs.setDeactivateOnDetection(False)
        FilenameSource = 'SourceEmission_'+str(epoch)+'.txt'
        output1 = TextOutput(FilenameSource)
        obs.onDetection(output1)
        sim.add(obs)

        obs2 = Observer()
        obs2.add(ObserverSurface( Sphere(obsPosition, 10.*Mpc)))
        obs2.setDeactivateOnDetection(True)
        FilenameObserver = 'Observer_'+str(epoch)+'.txt'
        output2 = TextOutput(FilenameObserver)
        obs2.onDetection(output2)
        sim.add(obs2)
    
        # Define the vMF source
        source = Source()
        source.add(SourcePosition(sourcePosition))
        source.add(SourceParticleType(nucleusId(1,1)))
        source.add(SourceEnergy(1 * EeV))
    
        # Here we need to add the vMF parameters
        muvec = Vector3d(float(mu[0]), float(mu[1]), float(mu[2]))
        source.add(SourceDirectedEmission(muvec,kappa))
        
        # Now we run the simulation
        sim.setShowProgress(True)
        sim.run(source, nbatch)
        output1.close()
        output2.close()
        
    run_sim(mu,kappa,nbatch,epoch)    
    
    # Get ids of particles hitting the source
    while not os.path.exists('Observer_'+str(epoch)+'.txt'):
        time.sleep(1)
    idhit = np.loadtxt('Observer_'+str(epoch)+'.txt', usecols=(2), unpack=True)
    
    # Get emission directions of particles
    virtualfile = open('SourceEmission_'+str(epoch)+'.txt')
    ids, px,py,pz = np.loadtxt(virtualfile, usecols=(2,8,9,10), unpack=True) #, skiprows=10)
    
    indices = [np.where(ids==ii)[0][0] for ii in idhit]
    
    x=np.array([px[indices],py[indices],pz[indices]]).T

    return x
    

def pdf_vonMises(x,mu,kappa):
    # See eq. (3.1) of PoS (ICRC2019) 447
    res=kappa*np.exp(-kappa*(1-x.dot(mu)))/(2.*np.pi*(1.-np.exp(-2*kappa)))
    return res

def weight(x,mu,kappa):
    # This routine calculates the reweighting for particles that should have been emitted according to 4pi
    p0=1./(4.*np.pi)
    p1=pdf_vonMises(x,mu,kappa)
    res = p0/p1 
    return res

def estimate_mu_kappa(x,weights,probhit=0.9):
    # This is a very simple learning algorithm
    
    #1) Just estimate the mean direction on the sky 
    aux = np.sum(np.array([x[:,0]*weights,x[:,1]*weights,x[:,2]*weights]),axis=1)
    mu=aux/np.linalg.norm(aux) #NOTE: mu needs to be normalized
    
    #2) Estimate the disc of the target on the emission sky
    aux = np.sum(((x[:,0]*mu[0])**2+(x[:,1]*mu[1])**2+(x[:,2]*mu[2])**2)*weights)/np.sum(weights)
    
    # Estimate kappa, such that on average the hit probability is probhit
    kappa = np.log(1.-probhit)/(aux-1.) 
    
    return mu,kappa

def retry(n:int=1, message:str=None, backupfunc:function=quit, *bargs, **bkwargs):
	"""
		tries decorated function n times after failing
            
        Parameter
        ---------
        n: int
            Number of retries untill the function is considered failed
        message: str
            Message to send if function failed
        backupfunc: function
            function to call when function that is retried failed n times
	"""
	def decorated_retry(f):
		def wrapper_retry(*args, **kwargs):
			for i in range(n):
				try:
					return f(*args, **kwargs)
				except BaseException:
					print(traceback.format_exc())
					if isinstance(message, type(None)):
						print(" ->retry", i+1,": function failed", i+1, "times, retrying...\n")
					else:
						print(" ->retry", i+1, ":", message)
			try:
				return f(*args, **kwargs)
			except BaseException:
				print(traceback.format_exc())
				print(f"retry end: function still failing after {n} retries, ending now")
			return backupfunc(*bargs, **bkwargs)
		
		return wrapper_retry
	return decorated_retry

@retry(n=3)
def sample(mu,kappa,nbatch=100,probhit=0.9,nepoch=200):
    batches_x=[]
    batches_w=[]
    mu_traj=[]
    kappa_traj=[]
    acceptance=[]
    for e in np.arange(nepoch):
        print('Processing epoch Nr.:',e)
        
        # Run CRPropa to generate a batch of particles
        # CRPropa passes the initial normalised emission directions x
        print('starting simulation...')
        y=run_batch(mu,kappa,nbatch,e)
        print('simulation done...')
        
        # Now calculate weights for the particles
        weights = []
        for xx in y:
            weights.append(weight(xx,mu,kappa))
        
        # Change lists to arrays
        y       = np.array(y)
        weights = np.array(weights)
        
        # Learn the parameters of the emission vMF distribution
        mu,kappa=estimate_mu_kappa(y,weights,probhit=probhit)
        acceptance.append(len(y)/float(nbatch))
        mu_traj.append(mu)
        kappa_traj.append(kappa)
        
        batches_x.append(y)
        batches_w.append(weights)
        
        
    x = np.copy(batches_x[0])
    w = np.copy(batches_w[0])
    
    for i in np.arange(1, len(batches_w)):
        x=np.append(x, batches_x[i], axis=0)
        w=np.append(w, batches_w[i], axis=0)
        
        
    return x,w,np.array(acceptance),np.array(mu_traj),np.array(kappa_traj)

# %%
# Set initial values
mu    = np.array([1,0,0])
kappa = 0.00001 # We start with an almost 4pi kernel
Phit  = 0.90 # Here we choose the desired hit probability. Note: it is a trade off between accuracy and exploration

# Start the learning algorithm
x,w,acceptance, mu_traj, kappa_traj = sample(mu,kappa,probhit=Phit,nbatch=100000,nepoch=4)
print(mu_traj)
print(kappa_traj)
# Out:
# Processing epoch Nr.: 0
# starting simulation...
# crpropa::ModuleList: Number of Threads: 32
# Run ModuleList
#   Started Wed Jul 22 02:57:03 2026 : [ Finished ] 100%    Needed: 00:00:02  - Finished at Wed Jul 22 02:57:05 2026
# simulation done...
# Processing epoch Nr.: 1
# starting simulation...
# crpropa::ModuleList: Number of Threads: 32
# Run ModuleList
#   Started Wed Jul 22 02:57:06 2026 : [ Finished ] 100%    Needed: 00:00:03  - Finished at Wed Jul 22 02:57:09 2026
# simulation done...
# Processing epoch Nr.: 2
# starting simulation...
# crpropa::ModuleList: Number of Threads: 32
# Run ModuleList
#   Started Wed Jul 22 02:57:09 2026 : [ Finished ] 100%    Needed: 00:00:03  - Finished at Wed Jul 22 02:57:12 2026
# simulation done...
# Processing epoch Nr.: 3
# starting simulation...
# crpropa::ModuleList: Number of Threads: 32
# Run ModuleList
#   Started Wed Jul 22 02:57:12 2026 : [ Finished ] 100%    Needed: 00:00:03  - Finished at Wed Jul 22 02:57:15 2026
# simulation done...
# [[-3.55263735e-05 -9.96827321e-01 -7.95945383e-02]
#  [ 1.33395101e-05 -5.41447265e-01 -8.40734714e-01]
#  [ 6.66028466e-06  6.43722161e-01 -7.65259289e-01]
#  [-1.21044313e-05  4.41612241e-01  8.97206012e-01]]
# [6.69652861 5.07906622 4.65817368 6.54226165]

# %% [markdown]
# ### Testing sampling results
#
# As can be seen in the following plot, the average sampling efficiency matches the desired hitting probability Phit:

# %%
import matplotlib.pylab as plt

plt.title('Acceptance rate as a function of epoch')
plt.plot(acceptance, label='sample acceptance',color='black')
plt.plot(acceptance*0+Phit, label='target acceptance',color='red')
plt.xlabel(r'$n_{\mathrm{epoch}}$')
plt.ylabel('Acceptance rate')
plt.legend()
plt.show()
